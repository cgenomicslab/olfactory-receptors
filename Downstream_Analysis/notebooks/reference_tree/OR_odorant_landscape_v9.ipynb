# %% [markdown]
# # OR–odorant functional landscape — v3
#
# Four activation matrices, each clustered (Jaccard + PAM, k=6) with hypergeometric + BH enrichment:
# - **baseline** — predictions, p ≥ 0.50
# - **calibrated** — predictions, p > 0.83
# - **hybrid_0.5** — M2OR ground truth (exact-sequence matched) over the p ≥ 0.50 fill
# - **hybrid_0.83** — M2OR ground truth over the p > 0.83 fill
#
# Per matrix: `heatmap_{name}` (rows in co-tuning order), `heatmap_{name}_tree_order` (rows in phylogenetic order), `spider_{name}` and `enrichment_{name}` (two views of the same enrichment). Plus `chemspace` (Class I vs II ligand descriptors). All figures exported as SVG.

# %%
import numpy as np, pandas as pd, matplotlib, re
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, leaves_list
from scipy.stats import hypergeom, mannwhitneyu
from sklearn.metrics import silhouette_score
from collections import Counter
from rdkit import Chem
from rdkit.Chem import Descriptors, Crippen, rdMolDescriptors, Lipinski
np.random.seed(0)
plt.rcParams.update({'font.family':'Liberation Sans','pdf.fonttype':42,'ps.fonttype':42,
    'axes.linewidth':0.8,'axes.edgecolor':'#c9c9c4','text.color':'#8a8a86','axes.labelcolor':'#c9c9c4',
    'xtick.color':'#8a8a86','ytick.color':'#8a8a86','savefig.dpi':300})

PROB  = "/home/izirdeli/Documents.cglab/olfactory-receptors/Downstream_Analysis/predictions/aggregated/Reference_Tree_Predictions/reference_median_probability_wide.csv"
PAIRS = "/home/izirdeli/Documents.cglab/olfactory-receptors/Model/Data_Preparation/processed/m2or_pairs_model.csv"                     # smiles_id <-> SMILES, experimental Responsive, Sequence
ODORS = "/home/izirdeli/Documents.cglab/DownStreamAnalysis/01.Data/metadata/inchi_smiles_odors.csv"                  # SMILES -> Odors
FASTA = "/home/izirdeli/Documents.cglab/olfactory-receptors/Phylogenetic_Analysis/data/ReferenceTree/PF13853.9606_7955_7740_7764_75743_137246.fa"  # reference sequences, headers = protein_id
CLASSES="/home/izirdeli/Documents.cglab/olfactory-receptors/Phylogenetic_Analysis/data/HumanTree/human433_OR_classes.csv" 
TREE="/home/izirdeli/Documents.cglab/olfactory-receptors/Phylogenetic_Analysis/data/HumanTree/human433_MFP_reorder.tree"
CLASS_I_COL='#7f1734'; CLASS_II_COL='#557c99'
OUTDIR = 'Figures'
K = 6
CALIB_THR = 0.83

# %% [markdown]
# ## 1 · Data: probability matrix, human ORs

# %%
import os; os.makedirs(OUTDIR, exist_ok=True)
prob=pd.read_csv(PROB,index_col=0)
hum_pids=[i for i in prob.index if str(i).startswith('9606')]
P=prob.loc[hum_pids]; lig_cols=list(P.columns); Pv=P.values
print('human probability matrix:',Pv.shape)
# Out:
# human probability matrix: (433, 754)

# %% [markdown]
# ## 2 · Experimental layer — exact amino-acid sequence match (23,782 pairs)

# %%
pid2seq={}; pid=None; buf=[]
for line in open(FASTA):
    line=line.rstrip()
    if line.startswith('>'):
        if pid: pid2seq[pid]=''.join(buf).upper()
        pid=line[1:].split()[0]; buf=[]
    else: buf.append(line)
if pid: pid2seq[pid]=''.join(buf).upper()
seq2pid={}
for p in hum_pids: seq2pid.setdefault(pid2seq[p],[]).append(p)
m=pd.read_csv(PAIRS,usecols=['Species','UniProt ID','Sequence','Responsive','smiles_id','mutation'])
hs=m[m['Species'].str.lower().str.contains('homo')].copy()
hs['Sequence']=hs['Sequence'].str.upper().str.strip()
hs['pid']=hs['Sequence'].map(lambda s: seq2pid.get(s,[None])[0])
matched=hs[hs['pid'].notna() & hs['smiles_id'].isin(set(lig_cols))]
exp=matched.groupby(['pid','smiles_id'])['Responsive'].max().reset_index()
print('overlapping human pairs:',len(exp),'(ground truth 23,782)')
# Out:
# overlapping human pairs: 23782 (ground truth 23,782)

# %% [markdown]
# ## 3 · Odor-tag map

# %%
pairs=pd.read_csv(PAIRS,usecols=['SMILES','smiles_id'])
sml2smiles=pairs.drop_duplicates('smiles_id').set_index('smiles_id')['SMILES'].to_dict()
odo=pd.read_csv(ODORS)
smiles2tags={s:[t.strip().lower() for t in o.split(',') if t.strip()]
             for s,o in zip(odo['SMILES'],odo['Odors']) if isinstance(o,str) and o.strip()}
sml2tags_all={sid:smiles2tags[sml2smiles[sid]] for sid in lig_cols if sml2smiles.get(sid) in smiles2tags}
print('tagged odorants:',len(sml2tags_all),'/',len(lig_cols))
# Out:
# tagged odorants: 575 / 754

# %%
sml2tags_all
# Out:
# {'SML0000': ['terpenic', 'peppery', 'herbal', 'pine', 'orange'],
#  'SML0001': ['minty', 'bready', 'spicy'],
#  'SML0002': ['mentholic'],
#  'SML0003': ['balsamic',
#   'winey',
#   'oily',
#   'solvent',
#   'fermented',
#   'sweet',
#   'alcoholic'],
#  'SML0005': ['soapy',
#   'honey',
#   'fatty',
#   'oily',
#   'citrus',
#   'floral',
#   'coconut',
#   'earthy',
#   'waxy'],
#  'SML0006': ['musty',
#   'fermented',
#   'pear',
#   'sweet',
#   'fruity',
#   'alcoholic',
#   'apple'],
#  'SML0007': ['cheesy', 'fatty', 'buttery', 'oily', 'sweet'],
#  'SML0008': ['powdery',
#   'musty',
#   'chocolate',
#   'nutty',
#   'earthy',
#   'roasted',
#   'woody',
#   'cocoa',
#   'medicinal',
#   'grassy'],
#  'SML0009': ['leathery',
#   'fatty',
#   'winey',
#   'solvent',
#   'fermented',
#   'ethereal',
#   'cocoa',
#   'alcoholic'],
#  'SML0010': ['rummy', 'winey', 'grape', 'sweet', 'waxy', 'fruity', 'ethereal'],
#  'SML0011': ['herbal',
#   'oily',
#   'fermented',
#   'nutty',
#   'sweet',
#   'fruity',
#   'ethereal'],
#  'SML0012': ['terpenic',
#   'cooling',
#   'herbal',
#   'sweet',
#   'camphoreous',
#   'earthy',
#   'pine',
#   'fresh',
#   'woody'],
#  'SML0013': ['bready',
#   'musty',
#   'hazelnut',
#   'potato',
#   'burnt',
#   'nutty',
#   'earthy',
#   'roasted',
#   'green'],
#  'SML0014': ['minty',
#   'terpenic',
#   'cooling',
#   'peppery',
#   'herbal',
#   'spicy',
#   'camphoreous',
#   'dry',
#   'pine',
#   'fresh',
#   'green',
#   'woody',
#   'hay'],
#  'SML0015': ['acidic', 'pungent', 'sharp', 'sour'],
#  'SML0016': ['cheesy', 'buttery', 'sharp', 'dairy', 'fruity', 'sour'],
#  'SML0017': ['sweet', 'hay'],
#  'SML0018': ['fatty', 'coconut', 'fresh', 'waxy'],
#  'SML0019': ['fatty',
#   'winey',
#   'oily',
#   'grape',
#   'brandy',
#   'nutty',
#   'cognac',
#   'sweet',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0020': ['clean',
#   'soapy',
#   'fatty',
#   'oily',
#   'sweet',
#   'floral',
#   'waxy',
#   'fruity'],
#  'SML0021': ['balsamic', 'milky', 'oily', 'sweet', 'waxy', 'fruity', 'creamy'],
#  'SML0022': ['odorless', 'waxy'],
#  'SML0023': ['apricot',
#   'musty',
#   'winey',
#   'pear',
#   'brandy',
#   'dairy',
#   'pineapple',
#   'sweet',
#   'banana',
#   'waxy',
#   'fruity',
#   'creamy'],
#  'SML0024': ['fatty', 'orris', 'violet', 'sweet', 'waxy'],
#  'SML0025': ['clove',
#   'spicy',
#   'phenolic',
#   'pungent',
#   'cinnamon',
#   'smoky',
#   'sweet',
#   'dry',
#   'savory',
#   'woody'],
#  'SML0026': ['muguet', 'lily', 'oily', 'sweet', 'floral', 'waxy'],
#  'SML0027': ['citrus', 'sweet', 'floral', 'rose', 'waxy', 'fruity'],
#  'SML0028': ['brown',
#   'coffee',
#   'potato',
#   'chocolate',
#   'nutty',
#   'beefy',
#   'roasted',
#   'ethereal',
#   'cocoa'],
#  'SML0029': ['acidic',
#   'cheesy',
#   'pungent',
#   'tropical',
#   'fatty',
#   'ripe',
#   'dairy',
#   'fruity',
#   'sour'],
#  'SML0030': ['odorless', 'buttery', 'sour'],
#  'SML0031': ['floral', 'fresh', 'green'],
#  'SML0032': ['citrus', 'sweet', 'floral', 'rose', 'green', 'woody'],
#  'SML0033': ['muguet', 'floral', 'aldehydic', 'woody'],
#  'SML0035': ['soapy', 'coconut', 'mushroom', 'waxy', 'creamy'],
#  'SML0036': ['fatty', 'orris', 'oily', 'sweet', 'waxy'],
#  'SML0037': ['odorless', 'oily', 'waxy'],
#  'SML0038': ['herbal',
#   'winey',
#   'sweet',
#   'green',
#   'waxy',
#   'aldehydic',
#   'fruity',
#   'vegetable',
#   'orange'],
#  'SML0039': ['fatty', 'orris', 'oily', 'cognac', 'waxy'],
#  'SML0041': ['cucumber',
#   'fatty',
#   'orris',
#   'citrus',
#   'floral',
#   'rose',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0042': ['natural',
#   'powdery',
#   'soapy',
#   'fatty',
#   'animal',
#   'sweet',
#   'floral',
#   'musk'],
#  'SML0043': ['odorless'],
#  'SML0044': ['herbal',
#   'fatty',
#   'citrus',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic',
#   'fruity',
#   'orange'],
#  'SML0045': ['odorless', 'fatty', 'waxy', 'creamy'],
#  'SML0046': ['hawthorn',
#   'powdery',
#   'herbal',
#   'anisic',
#   'sweet',
#   'floral',
#   'vanilla',
#   'fruity',
#   'hay'],
#  'SML0047': ['citrus', 'fresh', 'woody'],
#  'SML0048': ['fatty', 'waxy'],
#  'SML0049': ['acidic', 'cheesy', 'pungent', 'milky', 'dairy', 'sour'],
#  'SML0050': ['coffee', 'sweet', 'caramellic'],
#  'SML0051': ['soapy',
#   'odorless',
#   'fatty',
#   'oily',
#   'pineapple',
#   'coconut',
#   'waxy'],
#  'SML0052': ['soapy',
#   'fatty',
#   'citrus',
#   'pineapple',
#   'sweet',
#   'floral',
#   'green',
#   'waxy',
#   'aldehydic',
#   'orange'],
#  'SML0053': ['chocolate', 'sweet', 'vanilla', 'creamy'],
#  'SML0055': ['fatty',
#   'citrus',
#   'sweet',
#   'floral',
#   'coconut',
#   'rose',
#   'green',
#   'mushroom',
#   'waxy',
#   'aldehydic',
#   'orange'],
#  'SML0057': ['cheesy',
#   'fatty',
#   'fermented',
#   'pineapple',
#   'waxy',
#   'fruity',
#   'sour'],
#  'SML0058': ['cheesy', 'fatty', 'sour'],
#  'SML0059': ['burnt', 'nutty', 'green'],
#  'SML0060': ['fatty',
#   'winey',
#   'oily',
#   'fermented',
#   'cognac',
#   'floral',
#   'fruity'],
#  'SML0061': ['cheesy', 'fatty', 'oily', 'animal', 'waxy', 'vegetable'],
#  'SML0062': ['powdery',
#   'musty',
#   'coffee',
#   'potato',
#   'nutty',
#   'meaty',
#   'roasted',
#   'caramellic',
#   'green',
#   'cocoa'],
#  'SML0063': ['winey',
#   'chocolate',
#   'nutty',
#   'sweet',
#   'earthy',
#   'roasted',
#   'green',
#   'cocoa'],
#  'SML0064': ['popcorn',
#   'musty',
#   'coffee',
#   'hazelnut',
#   'potato',
#   'chocolate',
#   'nutty',
#   'roasted'],
#  'SML0065': ['brown',
#   'musty',
#   'potato',
#   'chocolate',
#   'fishy',
#   'nutty',
#   'earthy',
#   'roasted',
#   'green',
#   'cocoa'],
#  'SML0066': ['peppery', 'musty', 'potato', 'nutty', 'green', 'vegetable'],
#  'SML0067': ['popcorn',
#   'chocolate',
#   'burnt',
#   'nutty',
#   'roasted',
#   'almond',
#   'cocoa'],
#  'SML0068': ['musty',
#   'hazelnut',
#   'potato',
#   'chocolate',
#   'nutty',
#   'meaty',
#   'earthy',
#   'roasted',
#   'green',
#   'vegetable'],
#  'SML0069': ['clove',
#   'peppery',
#   'herbal',
#   'spicy',
#   'phenolic',
#   'musty',
#   'cinnamon',
#   'tea',
#   'warm',
#   'sweet',
#   'fresh',
#   'waxy',
#   'vegetable'],
#  'SML0070': ['potato', 'nutty', 'earthy', 'roasted'],
#  'SML0071': ['musty', 'nutty', 'earthy', 'green', 'vegetable'],
#  'SML0073': ['hyacinth', 'herbal', 'green'],
#  'SML0074': ['natural', 'citrus', 'sweet', 'rose', 'fresh'],
#  'SML0075': ['natural',
#   'brown',
#   'powdery',
#   'tobacco',
#   'pear',
#   'animal',
#   'sweet',
#   'coumarinic',
#   'fruity',
#   'musk'],
#  'SML0076': ['sweet', 'waxy', 'musk'],
#  'SML0077': ['pear', 'banana', 'fruity', 'ethereal', 'apple'],
#  'SML0078': ['minty', 'ketonic', 'mint', 'solvent', 'sweet', 'camphoreous'],
#  'SML0079': ['herbal',
#   'spicy',
#   'cheesy',
#   'ketonic',
#   'cinnamon',
#   'sweet',
#   'coconut',
#   'banana',
#   'green',
#   'woody',
#   'fruity',
#   'creamy'],
#  'SML0080': ['chemical',
#   'hawthorn',
#   'pungent',
#   'nutty',
#   'sweet',
#   'floral',
#   'coumarinic',
#   'vanilla',
#   'almond',
#   'cherry'],
#  'SML0082': ['soapy', 'fatty', 'sweet', 'dry', 'musk'],
#  'SML0083': ['minty', 'cooling', 'mentholic', 'mint'],
#  'SML0084': ['ketonic',
#   'solvent',
#   'sweet',
#   'camphoreous',
#   'fruity',
#   'ethereal'],
#  'SML0085': ['fatty',
#   'chicken',
#   'earthy',
#   'green',
#   'mushroom',
#   'waxy',
#   'aldehydic'],
#  'SML0086': ['musty', 'camphoreous', 'earthy'],
#  'SML0087': ['clove',
#   'spicy',
#   'phenolic',
#   'leathery',
#   'smoky',
#   'burnt',
#   'sweet',
#   'woody',
#   'vanilla',
#   'medicinal'],
#  'SML0088': ['cheesy', 'pungent', 'sour'],
#  'SML0090': ['sweet', 'floral', 'fresh'],
#  'SML0091': ['sharp',
#   'solvent',
#   'pear',
#   'pineapple',
#   'sweet',
#   'banana',
#   'fruity',
#   'ethereal'],
#  'SML0092': ['herbal', 'camphoreous', 'fresh', 'medicinal'],
#  'SML0093': ['herbal',
#   'pungent',
#   'oily',
#   'fresh',
#   'green',
#   'vegetable',
#   'grassy'],
#  'SML0094': ['lemon', 'citrus', 'fresh', 'fruity'],
#  'SML0095': ['citrus', 'sweet', 'floral', 'waxy', 'aldehydic', 'orange'],
#  'SML0096': ['pungent', 'buttery', 'sweet', 'caramellic', 'creamy'],
#  'SML0097': ['pungent',
#   'metallic',
#   'sweet',
#   'onion',
#   'garlic',
#   'horseradish',
#   'sulfurous'],
#  'SML0098': ['geranium', 'phenolic', 'metallic', 'floral', 'green'],
#  'SML0099': ['powdery', 'fatty', 'oily', 'sweet', 'floral', 'woody', 'musk'],
#  'SML0100': ['clove',
#   'spicy',
#   'balsamic',
#   'sweet',
#   'floral',
#   'malty',
#   'fresh',
#   'woody',
#   'fruity'],
#  'SML0101': ['herbal', 'sweet', 'camphoreous', 'earthy', 'pine', 'woody'],
#  'SML0103': ['lavender', 'sweet', 'floral', 'rose', 'green', 'waxy', 'fruity'],
#  'SML0104': ['spicy',
#   'phenolic',
#   'smoky',
#   'meaty',
#   'sweet',
#   'savory',
#   'woody',
#   'vanilla',
#   'medicinal'],
#  'SML0105': ['rummy',
#   'apricot',
#   'fatty',
#   'winey',
#   'pear',
#   'citrus',
#   'floral',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic',
#   'woody',
#   'fruity'],
#  'SML0106': ['estery',
#   'soapy',
#   'sweet',
#   'green',
#   'waxy',
#   'fruity',
#   'vegetable',
#   'apple'],
#  'SML0107': ['herbal', 'camphoreous', 'earthy', 'pine', 'woody', 'fruity'],
#  'SML0108': ['cheesy',
#   'pungent',
#   'chocolate',
#   'floral',
#   'fresh',
#   'banana',
#   'green',
#   'aldehydic',
#   'fruity'],
#  'SML0109': ['acidic', 'cheesy', 'buttery', 'dairy', 'fruity', 'sour'],
#  'SML0110': ['spicy', 'phenolic', 'sweet', 'floral'],
#  'SML0111': ['alliaceous',
#   'cabbage',
#   'oily',
#   'garlic',
#   'savory',
#   'creamy',
#   'vegetable',
#   'sulfurous'],
#  'SML0112': ['minty', 'phenolic', 'aromatic', 'warm', 'sweet', 'camphoreous'],
#  'SML0113': ['jasmine',
#   'herbal',
#   'peach',
#   'citrus',
#   'floral',
#   'earthy',
#   'green',
#   'mushroom',
#   'waxy',
#   'fruity',
#   'orange'],
#  'SML0114': ['powdery',
#   'hyacinth',
#   'honey',
#   'chocolate',
#   'fermented',
#   'sweet',
#   'floral',
#   'earthy',
#   'rose',
#   'green',
#   'cocoa'],
#  'SML0115': ['musty', 'pungent', 'hazelnut', 'nutty', 'sweet', 'roasted'],
#  'SML0116': ['clean', 'herbal', 'sweet', 'floral', 'pine', 'fresh', 'woody'],
#  'SML0117': ['bergamot', 'lavender', 'herbal', 'spicy', 'citrus', 'sweet'],
#  'SML0118': ['phenolic', 'sweet', 'floral', 'fruity', 'almond'],
#  'SML0120': ['sweet', 'floral', 'musk'],
#  'SML0122': ['powdery',
#   'musty',
#   'coffee',
#   'hazelnut',
#   'potato',
#   'burnt',
#   'nutty',
#   'earthy',
#   'roasted',
#   'cocoa'],
#  'SML0123': ['potato', 'chocolate', 'nutty', 'earthy', 'vegetable'],
#  'SML0124': ['green'],
#  'SML0125': ['acidic',
#   'cheesy',
#   'tobacco',
#   'milky',
#   'sharp',
#   'fruity',
#   'sour'],
#  'SML0126': ['cucumber',
#   'fatty',
#   'orris',
#   'melon',
#   'citrus',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0127': ['peppery',
#   'spicy',
#   'pungent',
#   'alliaceous',
#   'radish',
#   'onion',
#   'garlic',
#   'ethereal'],
#  'SML0128': ['brown',
#   'strawberry',
#   'burnt',
#   'pineapple',
#   'sweet',
#   'roasted',
#   'caramellic',
#   'savory',
#   'fruity'],
#  'SML0129': ['bready',
#   'musty',
#   'potato',
#   'oily',
#   'meaty',
#   'earthy',
#   'onion',
#   'brothy',
#   'savory',
#   'creamy',
#   'tomato',
#   'vegetable'],
#  'SML0130': ['pungent', 'fishy', 'oily', 'fruity'],
#  'SML0131': ['powdery', 'soapy', 'fatty', 'floral', 'dry', 'musk'],
#  'SML0132': ['musty',
#   'coffee',
#   'potato',
#   'winey',
#   'brandy',
#   'meaty',
#   'sweet',
#   'caramellic',
#   'mushroom',
#   'fruity',
#   'cocoa',
#   'vegetable'],
#  'SML0133': ['popcorn',
#   'musty',
#   'hazelnut',
#   'potato',
#   'nutty',
#   'meaty',
#   'earthy'],
#  'SML0134': ['musty',
#   'coffee',
#   'buttery',
#   'fermented',
#   'nutty',
#   'meaty',
#   'roasted',
#   'woody',
#   'cocoa'],
#  'SML0135': ['citrus', 'sweet', 'grapefruit', 'woody', 'orange'],
#  'SML0136': ['ozone', 'melon', 'floral', 'fresh', 'green', 'hay'],
#  'SML0137': ['minty', 'cooling', 'herbal', 'spicy', 'sweet', 'green'],
#  'SML0138': ['tobacco',
#   'fatty',
#   'smoky',
#   'floral',
#   'green',
#   'waxy',
#   'vegetable',
#   'grassy'],
#  'SML0139': ['minty',
#   'cooling',
#   'anise',
#   'mentholic',
#   'herbal',
#   'sweet',
#   'camphoreous',
#   'fresh',
#   'green'],
#  'SML0140': ['clean', 'fatty', 'oily', 'floral', 'rose', 'fresh', 'orange'],
#  'SML0142': ['cheesy', 'fatty', 'nutty', 'dairy', 'waxy'],
#  'SML0143': ['chicken',
#   'oily',
#   'sweet',
#   'earthy',
#   'green',
#   'mushroom',
#   'vegetable'],
#  'SML0144': ['cooked',
#   'meaty',
#   'sweet',
#   'onion',
#   'savory',
#   'mushroom',
#   'vegetable',
#   'sulfurous'],
#  'SML0146': ['lily', 'tropical', 'melon', 'sweet', 'floral', 'green', 'waxy'],
#  'SML0147': ['amber', 'powdery', 'sweet', 'fruity', 'musk'],
#  'SML0148': ['cedar', 'animal', 'woody', 'musk'],
#  'SML0149': ['clean', 'spicy', 'woody', 'musk'],
#  'SML0150': ['sharp', 'lemon', 'sweet'],
#  'SML0151': ['oily', 'leafy', 'floral', 'rose'],
#  'SML0152': ['metallic', 'sharp', 'lemon', 'sweet', 'green', 'fruity'],
#  'SML0153': ['popcorn',
#   'coffee',
#   'hazelnut',
#   'nutty',
#   'roasted',
#   'caramellic',
#   'cocoa',
#   'vegetable'],
#  'SML0154': ['odorless'],
#  'SML0155': ['odorless'],
#  'SML0156': ['jammy',
#   'raspberry',
#   'berry',
#   'ripe',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0157': ['cheesy',
#   'coffee',
#   'fatty',
#   'meaty',
#   'beefy',
#   'onion',
#   'roasted',
#   'garlic',
#   'savory',
#   'sulfurous'],
#  'SML0158': ['herbal',
#   'pungent',
#   'fatty',
#   'winey',
#   'oily',
#   'sweet',
#   'green',
#   'fruity',
#   'ethereal',
#   'alcoholic'],
#  'SML0159': ['herbal',
#   'musty',
#   'pungent',
#   'fatty',
#   'violet',
#   'leafy',
#   'sweet',
#   'fresh',
#   'banana',
#   'green',
#   'woody',
#   'fruity',
#   'vegetable',
#   'apple'],
#  'SML0160': ['bready',
#   'pungent',
#   'balsamic',
#   'winey',
#   'oily',
#   'solvent',
#   'fermented',
#   'sweet',
#   'alcoholic'],
#  'SML0163': ['clean',
#   'fatty',
#   'leafy',
#   'fresh',
#   'green',
#   'aldehydic',
#   'woody',
#   'fruity',
#   'vegetable',
#   'grassy'],
#  'SML0165': ['minty',
#   'terpenic',
#   'cooling',
#   'herbal',
#   'camphoreous',
#   'pine',
#   'fresh',
#   'green'],
#  'SML0166': ['cheesy', 'green', 'fruity', 'ethereal', 'cocoa', 'vegetable'],
#  'SML0168': ['minty', 'herbal', 'sweet'],
#  'SML0169': ['lemon', 'citrus'],
#  'SML0170': ['anise', 'phenolic', 'anisic', 'sweet', 'gasoline', 'ethereal'],
#  'SML0171': ['estery', 'ripe', 'solvent', 'pear', 'sweet', 'banana', 'fruity'],
#  'SML0172': ['geranium',
#   'powdery',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0173': ['fishy', 'animal'],
#  'SML0174': ['herbal', 'lemon', 'citrus', 'fresh', 'green', 'woody'],
#  'SML0176': ['acidic', 'cheesy', 'pungent', 'fermented', 'fruity'],
#  'SML0177': ['raspberry',
#   'natural',
#   'tobacco',
#   'tea',
#   'grape',
#   'plum',
#   'sweet',
#   'floral',
#   'earthy',
#   'rose',
#   'green',
#   'woody',
#   'fruity',
#   'apple'],
#  'SML0178': ['cucumber',
#   'fatty',
#   'chicken',
#   'oily',
#   'melon',
#   'citrus',
#   'nutty',
#   'brothy'],
#  'SML0179': ['cucumber',
#   'fatty',
#   'violet',
#   'melon',
#   'leafy',
#   'dry',
#   'green',
#   'vegetable'],
#  'SML0180': ['balsamic',
#   'tropical',
#   'orris',
#   'violet',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0182': ['citrus', 'aldehydic', 'orange'],
#  'SML0183': ['cucumber', 'citrus', 'aldehydic'],
#  'SML0184': ['minty',
#   'honey',
#   'tobacco',
#   'berry',
#   'plum',
#   'floral',
#   'rose',
#   'woody',
#   'fruity'],
#  'SML0186': ['citrus', 'floral', 'green', 'waxy', 'woody'],
#  'SML0187': ['tropical',
#   'berry',
#   'violet',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0189': ['fatty',
#   'citrus',
#   'fresh',
#   'green',
#   'aldehydic',
#   'fruity',
#   'orange'],
#  'SML0190': ['fatty', 'citrus', 'meaty', 'grapefruit', 'orange'],
#  'SML0191': ['cucumber',
#   'fatty',
#   'chicken',
#   'melon',
#   'nutty',
#   'green',
#   'waxy'],
#  'SML0192': ['bergamot',
#   'lavender',
#   'herbal',
#   'berry',
#   'citrus',
#   'floral',
#   'green',
#   'woody',
#   'vegetable',
#   'apple'],
#  'SML0193': ['cheesy', 'fatty', 'citrus', 'dairy', 'waxy', 'sour'],
#  'SML0194': ['odorless'],
#  'SML0195': ['herbal',
#   'musty',
#   'cabbage',
#   'metallic',
#   'chicken',
#   'fishy',
#   'earthy',
#   'savory',
#   'mushroom',
#   'vegetable'],
#  'SML0196': ['ozone',
#   'herbal',
#   'fatty',
#   'citrus',
#   'nutty',
#   'cognac',
#   'sweet',
#   'fresh',
#   'green',
#   'aldehydic'],
#  'SML0197': ['ripe',
#   'pear',
#   'pineapple',
#   'sweet',
#   'fresh',
#   'banana',
#   'green',
#   'fruity',
#   'cherry',
#   'apple'],
#  'SML0198': ['ketonic',
#   'winey',
#   'fermented',
#   'rum',
#   'dairy',
#   'sweet',
#   'banana',
#   'woody',
#   'fruity',
#   'ethereal'],
#  'SML0199': ['bready',
#   'pungent',
#   'berry',
#   'chocolate',
#   'fermented',
#   'nutty',
#   'fruity'],
#  'SML0200': ['pear', 'floral', 'woody', 'fruity', 'musk'],
#  'SML0206': ['celery',
#   'jasmin',
#   'fatty',
#   'oily',
#   'burnt',
#   'dairy',
#   'floral',
#   'fresh',
#   'waxy',
#   'fruity'],
#  'SML0208': ['onion', 'sulfurous'],
#  'SML0209': ['powdery', 'animal', 'musk'],
#  'SML0211': ['powdery',
#   'winey',
#   'berry',
#   'grape',
#   'plum',
#   'sweet',
#   'floral',
#   'fruity'],
#  'SML0212': ['spicy', 'cinnamon', 'warm', 'sweet'],
#  'SML0213': ['tropical', 'pineapple', 'sweet', 'banana', 'fruity', 'cherry'],
#  'SML0214': ['rummy', 'honey', 'pineapple', 'sweet', 'fruity'],
#  'SML0215': ['hyacinth', 'balsamic', 'floral', 'fruity'],
#  'SML0217': ['cooked', 'onion', 'garlic', 'vegetable', 'sulfurous'],
#  'SML0219': ['coffee',
#   'cabbage',
#   'potato',
#   'chicken',
#   'meaty',
#   'onion',
#   'roasted',
#   'sulfurous'],
#  'SML0220': ['sulfurous'],
#  'SML0221': ['meaty', 'roasted', 'vegetable', 'sulfurous'],
#  'SML0222': ['jasmin',
#   'powdery',
#   'jasmine',
#   'herbal',
#   'spicy',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0223': ['estery',
#   'herbal',
#   'fatty',
#   'berry',
#   'green',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0225': ['minty', 'mentholic', 'herbal'],
#  'SML0227': ['musty',
#   'leathery',
#   'tobacco',
#   'animal',
#   'sweet',
#   'earthy',
#   'medicinal'],
#  'SML0228': ['musty',
#   'coffee',
#   'alliaceous',
#   'berry',
#   'meaty',
#   'onion',
#   'green',
#   'cocoa'],
#  'SML0229': ['fishy', 'burnt', 'sour'],
#  'SML0231': ['sweet', 'camphoreous', 'pine'],
#  'SML0232': ['hazelnut', 'metallic', 'nutty'],
#  'SML0233': ['herbal',
#   'cucumber',
#   'fatty',
#   'oily',
#   'violet',
#   'leafy',
#   'nutty',
#   'green'],
#  'SML0235': ['meaty', 'onion', 'roasted', 'grapefruit', 'sulfurous'],
#  'SML0236': ['geranium',
#   'herbal',
#   'spicy',
#   'floral',
#   'camphoreous',
#   'earthy',
#   'rose',
#   'fresh',
#   'green',
#   'vegetable'],
#  'SML0237': ['fatty', 'milky', 'buttery', 'dairy', 'sweet', 'creamy'],
#  'SML0238': ['meaty', 'savory'],
#  'SML0239': ['lactonic', 'musty', 'fatty', 'milky', 'dairy', 'waxy', 'creamy'],
#  'SML0240': ['fatty',
#   'buttery',
#   'oily',
#   'peach',
#   'sweet',
#   'coconut',
#   'fresh',
#   'waxy',
#   'fruity',
#   'creamy'],
#  'SML0241': ['metallic', 'fatty', 'peach', 'sweet', 'fruity'],
#  'SML0242': ['fatty', 'buttery', 'oily', 'sweet', 'coconut', 'waxy', 'creamy'],
#  'SML0243': ['fatty',
#   'dairy',
#   'sweet',
#   'coconut',
#   'coumarinic',
#   'waxy',
#   'creamy'],
#  'SML0244': ['lactonic',
#   'apricot',
#   'ketonic',
#   'fatty',
#   'peach',
#   'coconut',
#   'fruity',
#   'creamy'],
#  'SML0245': ['coconut'],
#  'SML0246': ['nutty', 'sweet', 'caramellic', 'fruity'],
#  'SML0247': ['apricot',
#   'tropical',
#   'metallic',
#   'fatty',
#   'milky',
#   'buttery',
#   'oily',
#   'peach',
#   'dairy',
#   'sweet',
#   'coconut',
#   'fresh',
#   'fruity',
#   'creamy'],
#  'SML0248': ['lactonic',
#   'tropical',
#   'fatty',
#   'dairy',
#   'sweet',
#   'coconut',
#   'coumarinic',
#   'green',
#   'creamy'],
#  'SML0249': ['pungent',
#   'fatty',
#   'oily',
#   'sweet',
#   'fresh',
#   'green',
#   'fruity',
#   'vegetable',
#   'apple'],
#  'SML0250': ['fatty',
#   'lemon',
#   'citrus',
#   'sweet',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic',
#   'fruity',
#   'orange'],
#  'SML0251': ['terpenic', 'spicy', 'citrus', 'fresh', 'medicinal'],
#  'SML0252': ['terpenic', 'herbal', 'citrus', 'camphoreous', 'gasoline'],
#  'SML0253': ['cucumber', 'fatty', 'orris', 'melon', 'waxy'],
#  'SML0254': ['fatty', 'leafy', 'green', 'fruity'],
#  'SML0255': ['melon',
#   'pear',
#   'sweet',
#   'fresh',
#   'banana',
#   'green',
#   'fruity',
#   'grassy',
#   'apple'],
#  'SML0256': ['weedy',
#   'pungent',
#   'fatty',
#   'leafy',
#   'fresh',
#   'green',
#   'fruity',
#   'grassy',
#   'apple'],
#  'SML0257': ['fatty',
#   'milky',
#   'oily',
#   'dairy',
#   'green',
#   'creamy',
#   'vegetable'],
#  'SML0258': ['geranium', 'metallic', 'green'],
#  'SML0259': ['nutty',
#   'sweet',
#   'earthy',
#   'green',
#   'fruity',
#   'ethereal',
#   'alcoholic',
#   'vegetable'],
#  'SML0260': ['spicy',
#   'tropical',
#   'sweet',
#   'floral',
#   'vanilla',
#   'creamy',
#   'cherry'],
#  'SML0261': ['cooked',
#   'fatty',
#   'citrus',
#   'meaty',
#   'beefy',
#   'animal',
#   'sweet',
#   'brothy',
#   'savory',
#   'waxy',
#   'fruity'],
#  'SML0262': ['minty',
#   'anise',
#   'herbal',
#   'spicy',
#   'phenolic',
#   'anisic',
#   'sweet',
#   'green'],
#  'SML0263': ['anise', 'herbal', 'anisic', 'sweet', 'medicinal'],
#  'SML0264': ['clove',
#   'spicy',
#   'phenolic',
#   'musty',
#   'coffee',
#   'lemon',
#   'citrus',
#   'nutty',
#   'pine'],
#  'SML0265': ['phenolic', 'sharp', 'smoky', 'burnt', 'roasted'],
#  'SML0266': ['powdery',
#   'phenolic',
#   'balsamic',
#   'smoky',
#   'sweet',
#   'woody',
#   'medicinal'],
#  'SML0267': ['phenolic', 'coffee', 'sharp', 'smoky', 'sweet', 'medicinal'],
#  'SML0268': ['aromatic',
#   'alliaceous',
#   'tropical',
#   'citrus',
#   'onion',
#   'grapefruit',
#   'garlic',
#   'woody',
#   'sulfurous'],
#  'SML0269': ['bready',
#   'herbal',
#   'popcorn',
#   'chicken',
#   'nutty',
#   'onion',
#   'roasted',
#   'green',
#   'grassy'],
#  'SML0271': ['phenolic', 'smoky', 'sweet', 'vanilla', 'medicinal'],
#  'SML0272': ['chemical',
#   'coffee',
#   'meaty',
#   'onion',
#   'brothy',
#   'roasted',
#   'vegetable',
#   'sulfurous'],
#  'SML0273': ['phenolic',
#   'musty',
#   'coffee',
#   'fatty',
#   'chocolate',
#   'fermented',
#   'nutty',
#   'malty',
#   'green',
#   'fruity',
#   'cocoa',
#   'alcoholic'],
#  'SML0274': ['metallic',
#   'fishy',
#   'meaty',
#   'beefy',
#   'sweet',
#   'brothy',
#   'roasted',
#   'sulfurous'],
#  'SML0275': ['herbal', 'phenolic', 'musty', 'leathery', 'medicinal'],
#  'SML0276': ['herbal', 'fatty', 'meaty', 'green', 'mushroom', 'vegetable'],
#  'SML0277': ['tropical', 'roasted', 'sulfurous'],
#  'SML0278': ['bready', 'honey', 'sweet', 'floral', 'rose', 'fresh'],
#  'SML0279': ['honey',
#   'balsamic',
#   'tropical',
#   'sweet',
#   'floral',
#   'rose',
#   'fruity',
#   'cocoa'],
#  'SML0280': ['fishy', 'roasted'],
#  'SML0281': ['phenolic', 'musty'],
#  'SML0282': ['jammy',
#   'bready',
#   'strawberry',
#   'berry',
#   'burnt',
#   'sweet',
#   'caramellic',
#   'fruity'],
#  'SML0283': ['animal', 'floral', 'fruity'],
#  'SML0284': ['coffee',
#   'tropical',
#   'meaty',
#   'onion',
#   'roasted',
#   'caramellic',
#   'sulfurous'],
#  'SML0285': ['pungent',
#   'fermented',
#   'cognac',
#   'banana',
#   'fruity',
#   'ethereal',
#   'alcoholic'],
#  'SML0286': ['cheesy',
#   'pungent',
#   'fatty',
#   'chocolate',
#   'peach',
#   'green',
#   'aldehydic',
#   'fruity',
#   'ethereal',
#   'cocoa'],
#  'SML0288': ['phenolic', 'leathery', 'dry', 'woody', 'medicinal'],
#  'SML0289': ['balsamic',
#   'cinnamon',
#   'fatty',
#   'sweet',
#   'floral',
#   'rose',
#   'musk'],
#  'SML0290': ['alliaceous',
#   'tropical',
#   'chicken',
#   'meaty',
#   'grapefruit',
#   'savory',
#   'fruity',
#   'sulfurous'],
#  'SML0291': ['raspberry',
#   'tropical',
#   'pear',
#   'floral',
#   'grapefruit',
#   'fruity',
#   'sulfurous'],
#  'SML0292': ['herbal', 'spicy', 'pungent', 'green'],
#  'SML0293': ['clove',
#   'peppery',
#   'powdery',
#   'spicy',
#   'phenolic',
#   'smoky',
#   'sweet',
#   'woody'],
#  'SML0294': ['chemical',
#   'spicy',
#   'phenolic',
#   'musty',
#   'meaty',
#   'sweet',
#   'medicinal'],
#  'SML0295': ['fatty'],
#  'SML0296': ['phenolic', 'smoky', 'animal', 'savory', 'woody'],
#  'SML0297': ['sweet', 'vanilla', 'creamy'],
#  'SML0298': ['minty', 'tropical', 'peach', 'sweet', 'grapefruit', 'sulfurous'],
#  'SML0299': ['hawthorn',
#   'powdery',
#   'sweet',
#   'floral',
#   'coumarinic',
#   'vanilla',
#   'fruity',
#   'cherry',
#   'hay'],
#  'SML0300': ['phenolic', 'smoky', 'animal', 'medicinal'],
#  'SML0301': ['clove',
#   'powdery',
#   'spicy',
#   'phenolic',
#   'balsamic',
#   'sharp',
#   'sweet'],
#  'SML0302': ['sweet', 'caramellic'],
#  'SML0303': ['balsamic', 'sweet'],
#  'SML0304': ['alliaceous', 'onion', 'garlic', 'sulfurous'],
#  'SML0305': ['spicy',
#   'pungent',
#   'alliaceous',
#   'metallic',
#   'meaty',
#   'onion',
#   'garlic',
#   'green',
#   'mushroom',
#   'horseradish',
#   'sulfurous'],
#  'SML0306': ['spicy', 'balsamic', 'cinnamon', 'sweet', 'floral', 'fruity'],
#  'SML0307': ['powdery', 'hyacinth', 'spicy', 'balsamic', 'sweet', 'green'],
#  'SML0308': ['pungent', 'alliaceous', 'metallic', 'onion', 'garlic'],
#  'SML0309': ['pungent',
#   'radish',
#   'cabbage',
#   'berry',
#   'fishy',
#   'sweet',
#   'onion',
#   'green',
#   'fruity',
#   'creamy',
#   'tomato',
#   'vegetable',
#   'sulfurous'],
#  'SML0310': ['cooked',
#   'alliaceous',
#   'cabbage',
#   'meaty',
#   'onion',
#   'fresh',
#   'garlic',
#   'savory',
#   'vegetable',
#   'sulfurous'],
#  'SML0311': ['cabbage', 'onion', 'vegetable', 'sulfurous'],
#  'SML0312': ['alliaceous',
#   'tropical',
#   'metallic',
#   'burnt',
#   'earthy',
#   'onion',
#   'fresh',
#   'garlic',
#   'green',
#   'sulfurous'],
#  'SML0313': ['pungent',
#   'alliaceous',
#   'tropical',
#   'onion',
#   'garlic',
#   'green',
#   'vegetable',
#   'sulfurous'],
#  'SML0314': ['clean',
#   'herbal',
#   'spicy',
#   'cheesy',
#   'pungent',
#   'fatty',
#   'sharp',
#   'leafy',
#   'fresh',
#   'banana',
#   'green',
#   'aldehydic',
#   'fruity',
#   'vegetable',
#   'grassy',
#   'apple'],
#  'SML0315': ['sweet', 'ethereal', 'alcoholic', 'medicinal'],
#  'SML0317': ['estery',
#   'tropical',
#   'strawberry',
#   'berry',
#   'sharp',
#   'sweet',
#   'fresh',
#   'green',
#   'fruity',
#   'apple'],
#  'SML0318': ['metallic',
#   'ripe',
#   'pineapple',
#   'caramellic',
#   'fruity',
#   'tomato',
#   'sulfurous'],
#  'SML0319': ['estery',
#   'winey',
#   'buttery',
#   'sharp',
#   'pineapple',
#   'sweet',
#   'banana',
#   'green',
#   'fruity',
#   'orange',
#   'apple'],
#  'SML0320': ['pineapple', 'fruity', 'apple'],
#  'SML0321': ['rummy',
#   'weedy',
#   'winey',
#   'sharp',
#   'grape',
#   'brandy',
#   'sweet',
#   'green',
#   'fruity',
#   'ethereal'],
#  'SML0322': ['minty',
#   'musty',
#   'grape',
#   'sweet',
#   'floral',
#   'dry',
#   'fruity',
#   'medicinal',
#   'cherry'],
#  'SML0323': ['juicy',
#   'buttery',
#   'ripe',
#   'cognac',
#   'pineapple',
#   'banana',
#   'fruity',
#   'ethereal'],
#  'SML0324': ['honey', 'balsamic', 'cinnamon', 'plum', 'floral'],
#  'SML0325': ['estery',
#   'tropical',
#   'fatty',
#   'strawberry',
#   'pear',
#   'pineapple',
#   'sweet',
#   'banana',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0326': ['acidic',
#   'tropical',
#   'berry',
#   'pineapple',
#   'sweet',
#   'green',
#   'fruity',
#   'apple'],
#  'SML0327': ['honey',
#   'balsamic',
#   'anisic',
#   'sweet',
#   'floral',
#   'rose',
#   'cocoa'],
#  'SML0328': ['cheesy',
#   'winey',
#   'berry',
#   'fermented',
#   'brandy',
#   'fruity',
#   'apple'],
#  'SML0329': ['coffee',
#   'alliaceous',
#   'fatty',
#   'chicken',
#   'oily',
#   'smoky',
#   'burnt',
#   'meaty',
#   'caramellic',
#   'savory',
#   'sulfurous'],
#  'SML0330': ['herbal',
#   'lemon',
#   'citrus',
#   'sweet',
#   'floral',
#   'fresh',
#   'green',
#   'fruity'],
#  'SML0331': ['fatty',
#   'pear',
#   'sweet',
#   'fresh',
#   'banana',
#   'green',
#   'fruity',
#   'apple'],
#  'SML0332': ['apricot',
#   'rum',
#   'pineapple',
#   'sweet',
#   'floral',
#   'fruity',
#   'ethereal',
#   'apple'],
#  'SML0333': ['pungent',
#   'buttery',
#   'fermented',
#   'pineapple',
#   'sweet',
#   'banana',
#   'fruity',
#   'ethereal',
#   'creamy',
#   'apple'],
#  'SML0334': ['cooked',
#   'clean',
#   'metallic',
#   'sweet',
#   'onion',
#   'garlic',
#   'green',
#   'sulfurous'],
#  'SML0335': ['terpenic',
#   'celery',
#   'peppery',
#   'herbal',
#   'spicy',
#   'balsamic',
#   'rose',
#   'woody'],
#  'SML0336': ['weedy',
#   'soapy',
#   'herbal',
#   'cheesy',
#   'fatty',
#   'sweet',
#   'coconut',
#   'earthy',
#   'fresh',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0337': ['cheesy',
#   'pungent',
#   'fatty',
#   'buttery',
#   'oily',
#   'nutty',
#   'sweet',
#   'caramellic',
#   'creamy'],
#  'SML0338': ['pungent',
#   'winey',
#   'grape',
#   'brandy',
#   'nutty',
#   'cognac',
#   'meaty',
#   'earthy',
#   'green',
#   'ethereal',
#   'cocoa',
#   'alcoholic'],
#  'SML0339': ['coffee', 'fishy', 'meaty', 'sulfurous'],
#  'SML0340': ['balsamic', 'strawberry', 'sweet', 'fruity', 'cherry'],
#  'SML0341': ['coffee',
#   'burnt',
#   'nutty',
#   'meaty',
#   'earthy',
#   'roasted',
#   'savory',
#   'mushroom',
#   'cocoa',
#   'sulfurous'],
#  'SML0342': ['cabbage',
#   'metallic',
#   'onion',
#   'green',
#   'vegetable',
#   'sulfurous'],
#  'SML0343': ['coffee',
#   'alliaceous',
#   'meaty',
#   'onion',
#   'roasted',
#   'garlic',
#   'sulfurous'],
#  'SML0344': ['chicken',
#   'burnt',
#   'meaty',
#   'beefy',
#   'roasted',
#   'savory',
#   'horseradish',
#   'sulfurous'],
#  'SML0345': ['tropical', 'meaty', 'floral', 'sulfurous'],
#  'SML0346': ['minty',
#   'coffee',
#   'alliaceous',
#   'sharp',
#   'onion',
#   'garlic',
#   'horseradish',
#   'sulfurous'],
#  'SML0347': ['pungent',
#   'alliaceous',
#   'radish',
#   'onion',
#   'garlic',
#   'horseradish',
#   'vegetable',
#   'sulfurous'],
#  'SML0348': ['hyacinth', 'spicy', 'balsamic', 'sweet', 'floral'],
#  'SML0349': ['chemical',
#   'estery',
#   'brown',
#   'bready',
#   'musty',
#   'coffee',
#   'sweet',
#   'caramellic',
#   'alcoholic',
#   'sulfurous'],
#  'SML0350': ['chemical',
#   'phenolic',
#   'balsamic',
#   'sweet',
#   'floral',
#   'rose',
#   'fruity',
#   'almond'],
#  'SML0351': ['brown',
#   'bready',
#   'spicy',
#   'phenolic',
#   'sweet',
#   'caramellic',
#   'woody',
#   'almond'],
#  'SML0352': ['estery',
#   'tropical',
#   'ripe',
#   'sweet',
#   'banana',
#   'fruity',
#   'ethereal',
#   'apple'],
#  'SML0353': ['rummy',
#   'pungent',
#   'rum',
#   'sweet',
#   'fruity',
#   'ethereal',
#   'alcoholic',
#   'apple'],
#  'SML0354': ['lactonic',
#   'celery',
#   'burnt',
#   'nutty',
#   'coconut',
#   'coumarinic',
#   'woody'],
#  'SML0355': ['green'],
#  'SML0356': ['burnt', 'caramellic', 'fruity', 'hay'],
#  'SML0357': ['citrus', 'sweet', 'gasoline', 'fresh', 'orange'],
#  'SML0358': ['minty', 'spicy', 'mint', 'citrus', 'fresh', 'woody'],
#  'SML0361': ['estery',
#   'coffee',
#   'buttery',
#   'burnt',
#   'sweet',
#   'roasted',
#   'caramellic',
#   'fruity'],
#  'SML0362': ['clean', 'herbal', 'citrus'],
#  'SML0365': ['meaty', 'onion', 'green', 'sulfurous'],
#  'SML0367': ['terpenic', 'floral'],
#  'SML0368': ['terpenic',
#   'herbal',
#   'sharp',
#   'warm',
#   'earthy',
#   'pine',
#   'fresh',
#   'woody'],
#  'SML0369': ['minty', 'terpenic', 'herbal', 'aromatic'],
#  'SML0370': ['herbal', 'dry', 'pine', 'fresh', 'green', 'woody', 'hay'],
#  'SML0371': ['terpenic', 'sweet', 'pine', 'fresh', 'green', 'woody', 'hay'],
#  'SML0372': ['terpenic',
#   'spicy',
#   'oily',
#   'citrus',
#   'camphoreous',
#   'pine',
#   'green',
#   'woody'],
#  'SML0374': ['clove',
#   'spicy',
#   'phenolic',
#   'smoky',
#   'sweet',
#   'woody',
#   'vanilla',
#   'medicinal'],
#  'SML0375': ['tropical', 'meaty', 'savory', 'green', 'fruity', 'sulfurous'],
#  'SML0376': ['geranium', 'pungent', 'green'],
#  'SML0377': ['musty',
#   'pungent',
#   'nutty',
#   'fresh',
#   'aldehydic',
#   'fruity',
#   'ethereal',
#   'alcoholic'],
#  'SML0378': ['estery',
#   'powdery',
#   'tropical',
#   'fatty',
#   'berry',
#   'ripe',
#   'sweet',
#   'green',
#   'fruity',
#   'ethereal',
#   'apple'],
#  'SML0379': ['winey', 'fermented', 'sweet', 'ethereal'],
#  'SML0380': ['balsamic'],
#  'SML0381': ['powdery',
#   'honey',
#   'tobacco',
#   'chocolate',
#   'animal',
#   'sweet',
#   'floral',
#   'rose',
#   'waxy',
#   'sour'],
#  'SML0382': ['lactonic',
#   'fatty',
#   'milky',
#   'buttery',
#   'oily',
#   'peach',
#   'nutty',
#   'dairy',
#   'sweet',
#   'coconut',
#   'fresh',
#   'fruity',
#   'creamy'],
#  'SML0383': ['grape', 'sweet'],
#  'SML0384': ['natural', 'powdery', 'animal', 'musk'],
#  'SML0390': ['musty', 'animal', 'musk'],
#  'SML0391': ['geranium', 'powdery', 'herbal', 'balsamic', 'metallic', 'rose'],
#  'SML0395': ['powdery', 'grape', 'floral', 'orange'],
#  'SML0397': ['minty'],
#  'SML0398': ['oily', 'citrus', 'floral', 'fruity'],
#  'SML0399': ['soapy',
#   'citrus',
#   'sweet',
#   'floral',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0404': ['cheesy', 'fatty', 'coconut', 'waxy', 'creamy'],
#  'SML0407': ['clean', 'fatty', 'oily', 'sweet', 'floral', 'waxy', 'orange'],
#  'SML0408': ['odorless'],
#  'SML0413': ['jasmin', 'herbal', 'spicy', 'oily', 'fresh', 'green'],
#  'SML0414': ['herbal', 'earthy', 'green', 'woody', 'fruity'],
#  'SML0415': ['oily',
#   'fermented',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'fresh'],
#  'SML0416': ['herbal',
#   'spicy',
#   'musty',
#   'leafy',
#   'floral',
#   'earthy',
#   'fresh',
#   'green',
#   'woody'],
#  'SML0417': ['minty',
#   'herbal',
#   'spicy',
#   'musty',
#   'oily',
#   'melon',
#   'fermented',
#   'citrus',
#   'nutty',
#   'dairy',
#   'earthy',
#   'green',
#   'mushroom',
#   'waxy',
#   'woody',
#   'creamy'],
#  'SML0419': ['cheesy',
#   'musty',
#   'citrus',
#   'dairy',
#   'green',
#   'waxy',
#   'fruity',
#   'creamy',
#   'orange'],
#  'SML0420': ['minty', 'cooling', 'mentholic', 'musty', 'mint'],
#  'SML0421': ['chemical',
#   'herbal',
#   'spicy',
#   'phenolic',
#   'sweet',
#   'camphoreous',
#   'medicinal'],
#  'SML0422': ['balsamic', 'sweet'],
#  'SML0423': ['natural',
#   'weedy',
#   'herbal',
#   'cheesy',
#   'ketonic',
#   'musty',
#   'fatty',
#   'dairy',
#   'earthy',
#   'green',
#   'woody',
#   'fruity',
#   'apple'],
#  'SML0424': ['lavender',
#   'herbal',
#   'cheesy',
#   'ketonic',
#   'musty',
#   'fermented',
#   'sweet',
#   'earthy',
#   'fresh',
#   'green',
#   'mushroom',
#   'fruity',
#   'vegetable'],
#  'SML0425': ['jasmin',
#   'herbal',
#   'spicy',
#   'leafy',
#   'sweet',
#   'floral',
#   'fresh',
#   'green',
#   'fruity',
#   'grassy'],
#  'SML0426': ['fatty', 'peach', 'floral', 'orange'],
#  'SML0427': ['citrus', 'floral', 'fruity', 'orange'],
#  'SML0428': ['herbal',
#   'cheesy',
#   'ketonic',
#   'musty',
#   'oily',
#   'citrus',
#   'banana',
#   'green',
#   'fruity',
#   'creamy',
#   'apple'],
#  'SML0429': ['jammy',
#   'raspberry',
#   'powdery',
#   'berry',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity',
#   'cherry'],
#  'SML0430': ['mint', 'camphoreous', 'fresh'],
#  'SML0431': ['rummy',
#   'estery',
#   'winey',
#   'berry',
#   'cognac',
#   'pineapple',
#   'sweet',
#   'banana',
#   'green',
#   'fruity'],
#  'SML0432': ['natural',
#   'tropical',
#   'fatty',
#   'oily',
#   'grape',
#   'nutty',
#   'rum',
#   'cognac',
#   'rose',
#   'waxy',
#   'fruity'],
#  'SML0433': ['apricot',
#   'strawberry',
#   'pineapple',
#   'banana',
#   'fruity',
#   'ethereal',
#   'apple'],
#  'SML0434': ['berry',
#   'orris',
#   'sweet',
#   'floral',
#   'green',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0435': ['tropical',
#   'winey',
#   'pear',
#   'nutty',
#   'sweet',
#   'coconut',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0436': ['cheesy',
#   'cabbage',
#   'milky',
#   'sweet',
#   'garlic',
#   'fruity',
#   'cocoa',
#   'tomato',
#   'sulfurous'],
#  'SML0437': ['fishy', 'nutty', 'meaty'],
#  'SML0438': ['cooked',
#   'brown',
#   'coffee',
#   'burnt',
#   'nutty',
#   'meaty',
#   'beefy',
#   'vegetable',
#   'sulfurous'],
#  'SML0439': ['cheesy', 'musty', 'pungent', 'animal', 'floral'],
#  'SML0440': ['anise', 'spicy', 'aromatic', 'warm', 'sweet', 'floral', 'woody'],
#  'SML0441': ['powdery',
#   'sharp',
#   'nutty',
#   'sweet',
#   'fruity',
#   'almond',
#   'cherry'],
#  'SML0442': ['herbal',
#   'citrus',
#   'sweet',
#   'floral',
#   'dry',
#   'rose',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0443': ['lactonic',
#   'jasmin',
#   'natural',
#   'jasmine',
#   'tropical',
#   'oily',
#   'floral',
#   'green',
#   'fruity'],
#  'SML0444': ['herbal',
#   'cucumber',
#   'fatty',
#   'leafy',
#   'fresh',
#   'banana',
#   'green',
#   'waxy',
#   'vegetable'],
#  'SML0445': ['fatty', 'melon', 'pear', 'citrus', 'green', 'fruity'],
#  'SML0447': ['terpenic',
#   'cedar',
#   'cooling',
#   'mentholic',
#   'herbal',
#   'balsamic',
#   'mint',
#   'sweet',
#   'camphoreous',
#   'earthy',
#   'pine',
#   'fresh',
#   'woody'],
#  'SML0450': ['floral', 'earthy', 'green'],
#  'SML0453': ['cheesy', 'ketonic', 'buttery', 'meaty', 'dairy', 'fruity'],
#  'SML0454': ['apricot',
#   'winey',
#   'oily',
#   'solvent',
#   'fermented',
#   'sweet',
#   'fruity',
#   'alcoholic'],
#  'SML0455': ['fatty', 'oily', 'sweet', 'fruity'],
#  'SML0457': ['fatty', 'oily', 'grape', 'mushroom', 'creamy'],
#  'SML0458': ['winey', 'oily'],
#  'SML0459': ['cheesy', 'fatty', 'oily', 'mushroom'],
#  'SML0460': ['hyacinth', 'strawberry', 'floral'],
#  'SML0461': ['rummy',
#   'strawberry',
#   'rum',
#   'fresh',
#   'fruity',
#   'ethereal',
#   'apple'],
#  'SML0462': ['brandy', 'rum', 'fruity'],
#  'SML0463': ['apricot', 'pineapple', 'sweet', 'fruity', 'ethereal'],
#  'SML0464': ['cheesy', 'ripe', 'fishy', 'malty'],
#  'SML0465': ['anisic', 'sweet'],
#  'SML0467': ['minty',
#   'herbal',
#   'metallic',
#   'mint',
#   'sweet',
#   'camphoreous',
#   'fresh',
#   'sulfurous'],
#  'SML0468': ['cheesy'],
#  'SML0469': ['herbal', 'tobacco', 'sweet', 'coconut', 'coumarinic', 'creamy'],
#  'SML0470': ['gasoline'],
#  'SML0471': ['ripe',
#   'fermented',
#   'cognac',
#   'pineapple',
#   'sweet',
#   'banana',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0472': ['floral'],
#  'SML0473': ['estery',
#   'fatty',
#   'pear',
#   'cognac',
#   'pineapple',
#   'sweet',
#   'green',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0474': ['jasmin', 'jasmine', 'sweet', 'floral', 'fresh', 'fruity'],
#  'SML0475': ['clean', 'herbal', 'balsamic', 'oily', 'sweet'],
#  'SML0476': ['herbal',
#   'tropical',
#   'winey',
#   'oily',
#   'pear',
#   'green',
#   'fruity',
#   'grassy',
#   'apple'],
#  'SML0477': ['minty',
#   'cooling',
#   'mentholic',
#   'herbal',
#   'phenolic',
#   'camphoreous',
#   'green',
#   'woody',
#   'medicinal'],
#  'SML0479': ['geranium',
#   'powdery',
#   'spicy',
#   'fatty',
#   'lemon',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'fresh',
#   'waxy'],
#  'SML0480': ['estery',
#   'apricot',
#   'herbal',
#   'tropical',
#   'warm',
#   'peach',
#   'pineapple',
#   'sweet',
#   'floral',
#   'green',
#   'fruity',
#   'cherry',
#   'apple'],
#  'SML0481': ['jasmine', 'sweet', 'floral'],
#  'SML0483': ['lily', 'warm', 'animal', 'floral', 'green', 'fruity'],
#  'SML0484': ['phenolic', 'berry', 'fruity', 'medicinal'],
#  'SML0485': ['lily', 'hyacinth', 'honey', 'animal', 'rose'],
#  'SML0486': ['hazelnut', 'chocolate', 'nutty', 'roasted'],
#  'SML0487': ['jasmin',
#   'balsamic',
#   'ripe',
#   'sweet',
#   'fresh',
#   'banana',
#   'green',
#   'fruity',
#   'apple'],
#  'SML0488': ['cheesy', 'ripe', 'fishy'],
#  'SML0489': ['bready',
#   'musty',
#   'pungent',
#   'chocolate',
#   'malty',
#   'green',
#   'fruity',
#   'cocoa'],
#  'SML0491': ['brown',
#   'powdery',
#   'phenolic',
#   'odorless',
#   'milky',
#   'dairy',
#   'sweet',
#   'vanilla',
#   'creamy'],
#  'SML0492': ['phenolic', 'sweet'],
#  'SML0493': ['powdery', 'sweet', 'vanilla'],
#  'SML0495': ['minty',
#   'terpenic',
#   'cooling',
#   'herbal',
#   'warm',
#   'mint',
#   'camphoreous',
#   'woody',
#   'hay'],
#  'SML0497': ['jammy',
#   'phenolic',
#   'fatty',
#   'buttery',
#   'oily',
#   'sweet',
#   'dry',
#   'caramellic',
#   'fruity',
#   'creamy'],
#  'SML0498': ['cheesy',
#   'ketonic',
#   'musty',
#   'fatty',
#   'sweet',
#   'banana',
#   'green',
#   'fruity'],
#  'SML0499': ['buttery', 'nutty', 'caramellic'],
#  'SML0502': ['cheesy',
#   'fatty',
#   'buttery',
#   'dairy',
#   'sweet',
#   'green',
#   'waxy',
#   'fruity',
#   'creamy',
#   'sour'],
#  'SML0503': ['rummy', 'plum', 'brandy', 'rum', 'fruity', 'ethereal'],
#  'SML0505': ['jasmine',
#   'phenolic',
#   'metallic',
#   'smoky',
#   'burnt',
#   'animal',
#   'woody',
#   'medicinal'],
#  'SML0506': ['fatty', 'floral', 'rose', 'green', 'aldehydic', 'orange'],
#  'SML0507': ['cedar',
#   'mentholic',
#   'herbal',
#   'spicy',
#   'balsamic',
#   'sweet',
#   'camphoreous',
#   'pine',
#   'woody'],
#  'SML0509': ['acidic', 'cheesy', 'sharp', 'animal', 'green', 'fruity'],
#  'SML0510': ['cheesy', 'pungent', 'dairy', 'creamy', 'sour'],
#  'SML0511': ['odorless'],
#  'SML0512': ['balsamic'],
#  'SML0514': ['balsamic',
#   'chocolate',
#   'smoky',
#   'sweet',
#   'floral',
#   'green',
#   'woody',
#   'vanilla'],
#  'SML0515': ['herbal', 'spicy', 'musty', 'tea', 'warm', 'sweet'],
#  'SML0519': ['terpenic', 'fresh', 'woody'],
#  'SML0521': ['minty'],
#  'SML0522': ['minty',
#   'herbal',
#   'spicy',
#   'fatty',
#   'oily',
#   'fresh',
#   'green',
#   'cherry',
#   'grassy'],
#  'SML0523': ['herbal', 'camphoreous', 'fresh', 'woody'],
#  'SML0525': ['minty', 'clean', 'herbal', 'citrus', 'sweet', 'fresh', 'fruity'],
#  'SML0527': ['meaty', 'garlic', 'savory', 'ethereal', 'tomato', 'sulfurous'],
#  'SML0530': ['pungent', 'sweet', 'ethereal'],
#  'SML0531': ['jasmine', 'floral', 'green'],
#  'SML0532': ['potato',
#   'winey',
#   'sharp',
#   'nutty',
#   'sweet',
#   'floral',
#   'earthy',
#   'green',
#   'fruity',
#   'almond',
#   'vegetable'],
#  'SML0534': ['honey', 'tobacco', 'plum', 'floral', 'rose', 'fruity'],
#  'SML0535': ['chicken', 'meaty', 'onion', 'roasted', 'savory', 'sulfurous'],
#  'SML0536': ['marine',
#   'clean',
#   'ozone',
#   'phenolic',
#   'melon',
#   'fresh',
#   'green'],
#  'SML0538': ['cucumber',
#   'orris',
#   'melon',
#   'citrus',
#   'fresh',
#   'green',
#   'waxy',
#   'woody',
#   'vegetable'],
#  'SML0541': ['powdery',
#   'phenolic',
#   'musty',
#   'sweet',
#   'floral',
#   'fruity',
#   'orange'],
#  'SML0543': ['natural',
#   'fatty',
#   'melon',
#   'pear',
#   'pineapple',
#   'fresh',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0544': ['alliaceous',
#   'tropical',
#   'ripe',
#   'onion',
#   'garlic',
#   'fruity',
#   'vegetable',
#   'sulfurous'],
#  'SML0545': ['strawberry', 'sweet', 'caramellic', 'fruity'],
#  'SML0546': ['cedar', 'ketonic', 'phenolic', 'dry', 'woody'],
#  'SML0547': ['clean',
#   'soapy',
#   'fatty',
#   'citrus',
#   'pineapple',
#   'sweet',
#   'rose',
#   'fresh',
#   'waxy',
#   'fruity',
#   'creamy',
#   'orange'],
#  'SML0548': ['raspberry',
#   'strawberry',
#   'melon',
#   'pear',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'fresh',
#   'green',
#   'fruity'],
#  'SML0549': ['cucumber',
#   'orris',
#   'citrus',
#   'rose',
#   'green',
#   'waxy',
#   'fruity',
#   'orange'],
#  'SML0550': ['apricot',
#   'tropical',
#   'pineapple',
#   'sweet',
#   'banana',
#   'fruity',
#   'apple'],
#  'SML0551': ['jammy',
#   'jasmin',
#   'hawthorn',
#   'powdery',
#   'soapy',
#   'aromatic',
#   'metallic',
#   'strawberry',
#   'sweet',
#   'floral',
#   'cherry'],
#  'SML0553': ['herbal', 'metallic', 'citrus', 'waxy', 'aldehydic', 'orange'],
#  'SML0554': ['herbal', 'green', 'fruity', 'almond'],
#  'SML0557': ['raspberry', 'anise', 'anisic', 'sweet', 'green'],
#  'SML0559': ['cortex',
#   'balsamic',
#   'melon',
#   'leafy',
#   'floral',
#   'fresh',
#   'green',
#   'aldehydic'],
#  'SML0564': ['minty', 'mentholic', 'mint'],
#  'SML0566': ['ketonic', 'burnt', 'fruity'],
#  'SML0570': ['musty', 'floral', 'fresh', 'green'],
#  'SML0571': ['marine',
#   'clean',
#   'ozone',
#   'floral',
#   'fresh',
#   'green',
#   'aldehydic'],
#  'SML0572': ['balsamic', 'sweet', 'floral', 'rose'],
#  'SML0573': ['powdery',
#   'spicy',
#   'anisic',
#   'sweet',
#   'floral',
#   'green',
#   'vanilla',
#   'fruity'],
#  'SML0574': ['amber',
#   'metallic',
#   'fatty',
#   'citrus',
#   'dry',
#   'fresh',
#   'coumarinic',
#   'waxy',
#   'aldehydic',
#   'fruity'],
#  'SML0575': ['spicy', 'balsamic', 'cinnamon', 'warm', 'sweet'],
#  'SML0577': ['lily', 'fresh', 'green', 'waxy', 'aldehydic', 'woody'],
#  'SML0579': ['amber',
#   'powdery',
#   'balsamic',
#   'melon',
#   'citrus',
#   'sweet',
#   'floral',
#   'dry',
#   'fresh',
#   'green',
#   'aldehydic',
#   'woody',
#   'fruity',
#   'almond',
#   'cherry',
#   'orange'],
#  'SML0580': ['jammy',
#   'tropical',
#   'strawberry',
#   'berry',
#   'burnt',
#   'sweet',
#   'caramellic',
#   'fruity'],
#  'SML0581': ['tropical',
#   'plum',
#   'sweet',
#   'pine',
#   'green',
#   'woody',
#   'fruity',
#   'apple'],
#  'SML0582': ['lactonic',
#   'jasmin',
#   'jasmine',
#   'herbal',
#   'tea',
#   'oily',
#   'sweet',
#   'floral',
#   'green',
#   'mushroom'],
#  'SML0583': ['herbal', 'pineapple', 'green', 'fruity', 'apple'],
#  'SML0584': ['bergamot',
#   'lavender',
#   'pear',
#   'citrus',
#   'sweet',
#   'floral',
#   'green',
#   'woody',
#   'fruity'],
#  'SML0585': ['marine', 'ozone', 'floral', 'fresh', 'aldehydic', 'woody'],
#  'SML0586': ['muguet', 'powdery', 'floral', 'green'],
#  'SML0587': ['cooling',
#   'herbal',
#   'spicy',
#   'phenolic',
#   'smoky',
#   'camphoreous',
#   'woody',
#   'medicinal'],
#  'SML0588': ['lily', 'oily', 'violet', 'green', 'fruity'],
#  'SML0590': ['herbal', 'citrus', 'floral', 'fresh', 'woody'],
#  'SML0591': ['powdery',
#   'tea',
#   'orris',
#   'oily',
#   'violet',
#   'sweet',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0592': ['berry',
#   'mint',
#   'plum',
#   'sweet',
#   'floral',
#   'rose',
#   'green',
#   'woody',
#   'fruity',
#   'apple'],
#  'SML0594': ['herbal',
#   'aromatic',
#   'citrus',
#   'floral',
#   'grapefruit',
#   'fresh',
#   'green',
#   'woody'],
#  'SML0595': ['powdery',
#   'phenolic',
#   'leathery',
#   'sharp',
#   'nutty',
#   'sweet',
#   'floral',
#   'green'],
#  'SML0596': ['celery',
#   'jasmin',
#   'jasmine',
#   'herbal',
#   'spicy',
#   'citrus',
#   'floral',
#   'woody',
#   'fruity'],
#  'SML0597': ['spicy',
#   'phenolic',
#   'warm',
#   'sweet',
#   'floral',
#   'fresh',
#   'green',
#   'vanilla'],
#  'SML0598': ['clove', 'spicy', 'tea', 'sweet', 'floral'],
#  'SML0599': ['balsamic', 'tobacco', 'animal', 'floral', 'dry', 'waxy', 'musk'],
#  'SML0601': ['soapy', 'animal', 'musk'],
#  'SML0605': ['radish', 'cabbage', 'buttery', 'burnt', 'creamy', 'sour'],
#  'SML0607': ['musk'],
#  'SML0616': ['odorless'],
#  'SML0617': ['odorless'],
#  'SML0650': ['pungent', 'winey', 'sweet', 'caramellic', 'green', 'ethereal'],
#  'SML0652': ['powdery', 'sweet', 'dry', 'musk'],
#  'SML0653': ['musty', 'sweet', 'floral', 'musk'],
#  'SML0654': ['animal', 'sweet', 'musk'],
#  'SML0655': ['lily', 'citrus', 'sweet', 'floral', 'fresh'],
#  'SML0657': ['amber', 'powdery', 'sweet', 'dry', 'fruity', 'musk'],
#  'SML0658': ['amber', 'herbal', 'sweet', 'dry', 'creamy', 'musk'],
#  'SML0661': ['amber', 'balsamic', 'animal', 'sweet', 'musk'],
#  'SML0663': ['amber', 'oily', 'animal', 'sweet', 'musk'],
#  'SML0664': ['amber', 'powdery', 'dry', 'musk'],
#  'SML0665': ['clean', 'animal', 'sweet', 'dry', 'musk'],
#  'SML0666': ['clean', 'animal', 'sweet', 'waxy', 'musk'],
#  'SML0667': ['sweet', 'waxy', 'woody', 'fruity', 'musk'],
#  'SML0669': ['fatty', 'warm', 'sweet', 'waxy', 'fruity', 'musk'],
#  'SML0670': ['oily', 'animal', 'sweet', 'floral', 'fruity', 'musk'],
#  'SML0671': ['weedy', 'clean', 'herbal', 'citrus', 'floral', 'fresh'],
#  'SML0672': ['jasmin', 'herbal', 'oily', 'floral', 'fresh', 'green'],
#  'SML0673': ['lavender', 'citrus', 'floral', 'fresh', 'woody'],
#  'SML0674': ['floral'],
#  'SML0677': ['jasmine', 'balsamic', 'floral', 'fresh', 'green'],
#  'SML0678': ['lily', 'citrus', 'sweet', 'floral', 'fresh'],
#  'SML0679': ['soapy',
#   'musty',
#   'leathery',
#   'citrus',
#   'sweet',
#   'rose',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0681': ['geranium', 'spicy', 'floral', 'rose'],
#  'SML0682': ['orangeflower', 'powdery', 'sweet', 'floral', 'orange'],
#  'SML0683': ['geranium',
#   'muguet',
#   'lily',
#   'honey',
#   'tropical',
#   'floral',
#   'rose',
#   'fresh',
#   'green'],
#  'SML0685': ['floral', 'green'],
#  'SML0687': ['fatty', 'peach', 'coconut', 'waxy', 'fruity', 'creamy'],
#  'SML0688': ['metallic', 'fatty', 'lemon', 'citrus', 'aldehydic'],
#  'SML0689': ['melon', 'green', 'mushroom', 'fruity'],
#  'SML0690': ['juicy',
#   'clean',
#   'cucumber',
#   'fatty',
#   'melon',
#   'fresh',
#   'green',
#   'waxy',
#   'fruity',
#   'vegetable'],
#  'SML0691': ['bergamot', 'lavender', 'herbal', 'floral', 'fresh', 'green'],
#  'SML0692': ['spicy', 'metallic', 'rose', 'green'],
#  'SML0693': ['metallic', 'lemon', 'citrus', 'floral', 'fresh', 'waxy'],
#  'SML0694': ['lactonic', 'jasmin', 'peach', 'floral', 'fruity'],
#  'SML0695': ['jasmin',
#   'juicy',
#   'powdery',
#   'tropical',
#   'oily',
#   'sweet',
#   'floral',
#   'rose',
#   'woody',
#   'fruity'],
#  'SML0696': ['apricot',
#   'balsamic',
#   'ripe',
#   'peach',
#   'pineapple',
#   'sweet',
#   'floral',
#   'rose',
#   'fruity',
#   'apple'],
#  'SML0698': ['lactonic',
#   'jasmine',
#   'herbal',
#   'spicy',
#   'fatty',
#   'sweet',
#   'floral',
#   'waxy',
#   'fruity',
#   'creamy'],
#  'SML0699': ['clean', 'rose', 'fresh', 'waxy', 'aldehydic'],
#  'SML0700': ['powdery',
#   'spicy',
#   'anisic',
#   'sweet',
#   'floral',
#   'fruity',
#   'cherry'],
#  'SML0701': ['citrus', 'sweet', 'floral', 'fresh', 'waxy', 'woody'],
#  'SML0702': ['clean',
#   'lily',
#   'herbal',
#   'violet',
#   'sweet',
#   'floral',
#   'rose',
#   'fresh',
#   'green'],
#  'SML0703': ['tropical', 'pineapple', 'sweet', 'waxy', 'fruity'],
#  'SML0704': ['jasmine', 'floral', 'green', 'fruity'],
#  'SML0706': ['jasmin',
#   'apricot',
#   'tropical',
#   'plum',
#   'pineapple',
#   'sweet',
#   'floral',
#   'fresh',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0707': ['marine', 'citrus', 'floral', 'aldehydic'],
#  'SML0708': ['jasmin', 'herbal', 'oily', 'floral', 'coconut', 'rose', 'green'],
#  'SML0709': ['lactonic',
#   'metallic',
#   'buttery',
#   'plum',
#   'floral',
#   'coconut',
#   'waxy'],
#  'SML0710': ['jasmin', 'jasmine', 'sweet', 'floral', 'banana', 'fruity'],
#  'SML0712': ['cheesy',
#   'fatty',
#   'milky',
#   'buttery',
#   'oily',
#   'dairy',
#   'sweet',
#   'waxy',
#   'creamy'],
#  'SML0713': ['lactonic',
#   'fatty',
#   'buttery',
#   'dairy',
#   'coconut',
#   'waxy',
#   'creamy'],
#  'SML0715': ['minty',
#   'bergamot',
#   'herbal',
#   'fatty',
#   'anisic',
#   'mint',
#   'citrus',
#   'floral',
#   'rose',
#   'grapefruit',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic',
#   'woody',
#   'apple'],
#  'SML0717': ['jasmin', 'tropical', 'oily', 'peach', 'fresh', 'fruity'],
#  'SML0718': ['muguet',
#   'melon',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'fresh',
#   'green',
#   'waxy',
#   'aldehydic'],
#  'SML0721': ['spicy', 'cinnamon'],
#  'SML0722': ['spicy', 'metallic', 'citrus', 'dry'],
#  'SML0723': ['powdery',
#   'honey',
#   'tropical',
#   'sweet',
#   'floral',
#   'rose',
#   'green',
#   'waxy',
#   'fruity',
#   'apple'],
#  'SML0725': ['strawberry', 'berry', 'sweet', 'caramellic', 'fruity'],
#  'SML0726': ['powdery',
#   'balsamic',
#   'plum',
#   'sweet',
#   'floral',
#   'coumarinic',
#   'vanilla',
#   'fruity',
#   'cherry'],
#  'SML0727': ['tropical',
#   'leafy',
#   'peach',
#   'floral',
#   'rose',
#   'fresh',
#   'green',
#   'fruity',
#   'apple'],
#  'SML0728': ['soapy',
#   'tropical',
#   'pear',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'grapefruit',
#   'fruity'],
#  'SML0729': ['fatty',
#   'milky',
#   'oily',
#   'sweet',
#   'coconut',
#   'coumarinic',
#   'creamy'],
#  'SML0730': ['musty', 'fatty', 'milky', 'buttery', 'oily', 'dairy', 'creamy'],
#  'SML0731': ['geranium',
#   'powdery',
#   'honey',
#   'tropical',
#   'grape',
#   'citrus',
#   'sweet',
#   'floral',
#   'rose',
#   'waxy',
#   'fruity',
#   'vegetable'],
#  'SML0732': ['hawthorn',
#   'powdery',
#   'balsamic',
#   'anisic',
#   'sweet',
#   'floral',
#   'vanilla',
#   'hay'],
#  'SML0733': ['lemon', 'citrus', 'fresh', 'green', 'aldehydic'],
#  'SML0734': ['raspberry',
#   'apricot',
#   'tropical',
#   'peach',
#   'sweet',
#   'rose',
#   'fresh',
#   'green',
#   'waxy',
#   'fruity'],
#  'SML0736': ['herbal', 'tobacco', 'warm', 'sweet'],
#  'SML0737': ['powdery', 'fatty', 'sweet', 'musk'],
#  'SML0738': ['powdery', 'fatty', 'anisic', 'animal', 'woody', 'musk'],
#  'SML0739': ['geranium', 'floral', 'rose', 'fruity', 'musk'],
#  'SML0740': ['acidic',
#   'cheesy',
#   'fatty',
#   'chicken',
#   'oily',
#   'roasted',
#   'savory',
#   'fruity'],
#  'SML0741': ['cheesy', 'fruity', 'sour'],
#  'SML0744': ['cheesy', 'fatty', 'green', 'waxy', 'sour'],
#  'SML0745': ['musty',
#   'coffee',
#   'hazelnut',
#   'chocolate',
#   'burnt',
#   'nutty',
#   'roasted',
#   'caramellic',
#   'almond',
#   'cocoa'],
#  'SML0748': ['green', 'fruity'],
#  'SML0749': ['meaty', 'fruity', 'sulfurous'],
#  'SML0750': ['orangeflower', 'powdery', 'honey', 'sweet', 'floral', 'orange'],
#  'SML0768': ['herbal', 'musty', 'earthy', 'fresh', 'green'],
#  'SML0770': ['gasoline', 'woody']}

# %% [markdown]
# ## 4 · Receptor classes and phylogenetic row order

# %%
cls=pd.read_csv(CLASSES)
pid2class={r.leaf_id:('I' if r.OR_class.split('_')[1]=='I' else 'II') for r in cls.itertuples()}
n_I=sum(v=='I' for v in pid2class.values()); n_II=sum(v=='II' for v in pid2class.values())
tree_order=re.findall(r'[\(,]([^(),:;]+):', open(TREE).read())   # ladderized tip order
assert set(tree_order)==set(hum_pids)
print('Class I:',n_I,'Class II:',n_II,'| tree tips:',len(tree_order))
# Out:
# Class I: 62 Class II: 371 | tree tips: 433

# %% [markdown]
# ## 5 · Palette and helpers

# %%
theme_rules = [
    (('acidic','sour','cheesy','dairy'),                       'Acid / Dairy / Cheese',       '#543005'),
    (('chemical','potato','vanilla','roasted','phenolic','popcorn','spicy'),'Roasted / Phenolic / Spice','#ae7121'),
    (('plum','jasmine','floral','balsamic'),                   'Floral / Balsamic',           '#e7cf94'),
    (('lavender','violet','green','fresh','herbal','citrus'),  'Fresh / Green / Herbal',      '#98d7cd'),
    (('cognac','coconut','pineapple','aldehydic','fruity','waxy','buttery'),'Fruity / Fatty / Aldehydic','#98d7cd'),
    (('alcoholic','ethereal','medicinal','fermented','smoky','rum','solvent'),'Fermented / Solvent','#24877f'),
    (('musk','animal','grapefruit'),                           'Musk / Animal',               '#003c30')]
SHORT={'Acid / Dairy / Cheese':'Acid·Dairy','Roasted / Phenolic / Spice':'Roasted·Spice','Floral / Balsamic':'Floral',
       'Fresh / Green / Herbal':'Fresh·Green','Fruity / Fatty / Aldehydic':'Fruity·Fatty','Fermented / Solvent':'Fermented','Musk / Animal':'Musk·Animal'}

def save(fig,name):
    fig.savefig(f'{OUTDIR}/{name}.svg', bbox_inches='tight'); plt.close(fig)

def kmedoids(D,k,n_init=15,seed=0):
    rng=np.random.default_rng(seed); n=len(D); best=None
    for _ in range(n_init):
        med=rng.choice(n,k,replace=False)
        for _ in range(300):
            lab=D[:,med].argmin(1); nm=med.copy()
            for c in range(k):
                idx=np.where(lab==c)[0]
                if len(idx): nm[c]=idx[D[np.ix_(idx,idx)].sum(1).argmin()]
            if set(nm)==set(med): med=nm; break
            med=nm
        lab=D[:,med].argmin(1); cost=D[np.arange(n),med[lab]].sum()
        if best is None or cost<best[0]: best=(cost,lab.copy())
    return best[1]

def bh(p):
    p=np.asarray(p); m=len(p); o=np.argsort(p); r=p[o]
    q=np.minimum.accumulate((r*m/(np.arange(m)+1))[::-1])[::-1]; out=np.empty(m); out[o]=np.clip(q,0,1); return out

def cluster_and_enrich(X,K=6):
    cols=np.array(lig_cols); keep=X.sum(0)>0; lig,Xn=cols[keep],X[:,keep]
    Dj=np.nan_to_num(squareform(pdist(Xn.T,'jaccard'))); lab=kmedoids(Dj,K)
    s2t={s:sml2tags_all[s] for s in lig if s in sml2tags_all}
    tagged=np.array([s in s2t for s in lig]); tagN=Counter([t for s in lig[tagged] for t in s2t[s]]); N=int(tagged.sum())
    tags=[t for t,c in tagN.items() if c>=5]; rows=[]
    for c in range(K):
        mem=[s for s in lig[lab==c] if s in s2t]; n=len(mem); ct=Counter([t for s in mem for t in s2t[s]])
        for t in tags:
            kk=ct.get(t,0); Kt=tagN[t]; e=n*Kt/N; oe=kk/e if e>0 else 0
            p=hypergeom.sf(kk-1,N,Kt,n) if kk>0 else 1.0
            rows.append([c,n,t,kk,Kt,round(e,3),round(oe,3),p])
    enr=pd.DataFrame(rows,columns=['cluster','n','tag','obs','tag_total','exp','obs_exp','p'])
    enr['fdr']=bh(enr['p'].values); sig=enr[(enr.fdr<0.05)&(enr.obs_exp>1)]
    # bijective theme assignment: every cluster gets a DISTINCT colour
    score={}
    for c in range(K):
        s=sig[sig.cluster==c]
        for ti,(keys,nm,col) in enumerate(theme_rules):
            hit=s[s.tag.isin(keys)]
            if len(hit): score[(c,ti)]=float(hit.obs_exp.max())
    meta={c:None for c in range(K)}; used=set()
    for (c,ti),sc in sorted(score.items(),key=lambda x:-x[1]):
        keys,nm,col=theme_rules[ti]
        if meta[c] is None and col not in used:
            meta[c]=dict(name=nm,color=col,size=int((lab==c).sum())); used.add(col)
    palette=list(dict.fromkeys(col for _,_,col in theme_rules))
    for c in range(K):
        if meta[c] is None:
            col=next((x for x in palette if x not in used),'#8a8a8a')
            top=sig[sig.cluster==c].sort_values('obs_exp',ascending=False).tag.tolist()
            meta[c]=dict(name=top[0].capitalize() if top else f'cluster{c}',color=col,size=int((lab==c).sum())); used.add(col)
    order={col:i for i,col in enumerate(palette)}
    cl_order=sorted(range(K),key=lambda c: order.get(meta[c]['color'],99))
    return lig,Xn,lab,enr,sig,meta,cl_order

# %% [markdown]
# ### Activation heatmap — class stripe (left), breadth (right); rows in co-tuning **or** phylogenetic order

# %%
def activation_heatmap(lig,Xn,lab,meta,cl_order,name,title,subtitle,roworder='cotuning',K=6):
    if roworder=='tree':
        ridx={p:i for i,p in enumerate(hum_pids)}; row_pos=np.array([ridx[p] for p in tree_order])
        ylab='433 human ORs (phylogenetic order)'; fname=f'heatmap_{name}_tree_order'
    else:
        row_pos=leaves_list(linkage(squareform(np.nan_to_num(squareform(pdist(Xn,'jaccard')))),'average'))
        ylab='433 human ORs (co-tuning order)'; fname=f'heatmap_{name}'
    col_index=[]; bounds=[]; pos=0
    for c in cl_order:
        idx=np.where(lab==c)[0]
        if len(idx)>2: idx=idx[leaves_list(linkage(np.nan_to_num(pdist(Xn[:,idx].T,'jaccard')),'average'))]
        col_index+=idx.tolist(); pos+=len(idx); bounds.append(pos)
    col_index=np.array(col_index); M=Xn[np.ix_(row_pos,col_index)]; starts=[0]+bounds[:-1]
    fig=plt.figure(figsize=(12.4,7.6))
    gs=fig.add_gridspec(2,3,width_ratios=[0.11,4,0.11],height_ratios=[0.14,4],hspace=0.028,wspace=0.02,left=0.055,right=0.94,top=0.83,bottom=0.135)
    ax=fig.add_subplot(gs[1,1])
    ax.imshow(M,aspect='auto',cmap=ListedColormap(['#F4F1EA','#2E4057']),interpolation='nearest',rasterized=True)
    ax.set_xticks([]); ax.set_yticks([])
    for sp in ax.spines.values(): sp.set_edgecolor('#bbb'); sp.set_linewidth(0.6)
    for i in range(1,len(bounds)): ax.axvline(starts[i]-0.5,color='white',lw=1.8)
    ax.set_xlabel(f'{len(lig)} odorants — co-tuning cluster (Jaccard, PAM, k={K})',fontsize=10.5,labelpad=8,color='#8a8a86')
    ax.set_ylabel(ylab,fontsize=10.5,color='#8a8a86')
    axtop=fig.add_subplot(gs[0,1],sharex=ax)
    axtop.imshow(np.array([[matplotlib.colors.to_rgb(meta[lab[j]]['color']) for j in col_index]]),aspect='auto',interpolation='nearest',extent=[0,len(col_index),0,1])
    axtop.set_xlim(0,len(col_index)); axtop.set_ylim(0,1); axtop.set_xticks([]); axtop.set_yticks([])
    for sp in axtop.spines.values(): sp.set_visible(False)
    for i,c in enumerate(cl_order):
        axtop.text((starts[i]+bounds[i])/2,1.55,SHORT.get(meta[c]['name'],meta[c]['name'][:10]),ha='center',va='bottom',fontsize=9,color=meta[c]['color'],fontweight='bold',clip_on=False)
    axcls=fig.add_subplot(gs[1,0],sharey=ax)
    axcls.imshow(np.array([[matplotlib.colors.to_rgb(CLASS_I_COL if pid2class[hum_pids[j]]=='I' else CLASS_II_COL)] for j in row_pos]),aspect='auto',interpolation='nearest')
    axcls.set_xticks([]); axcls.set_yticks([])
    for sp in axcls.spines.values(): sp.set_visible(False)
    axcls.set_xlabel('class',fontsize=7.5,color='#8a8a86',labelpad=4)
    axbr=fig.add_subplot(gs[1,2],sharey=ax)
    axbr.imshow(Xn.sum(1)[row_pos].reshape(-1,1),aspect='auto',cmap='Greys',interpolation='nearest',rasterized=True)
    axbr.set_xticks([]); axbr.set_yticks([])
    for sp in axbr.spines.values(): sp.set_visible(False)
    axbr.set_xlabel('breadth',fontsize=7.5,color='#8a8a86',labelpad=4)
    ax.legend(handles=[Patch(fc=CLASS_I_COL,label='Class I'),Patch(fc=CLASS_II_COL,label='Class II'),Patch(fc='#2E4057',label='binding'),Patch(fc='#F4F1EA',ec='#bbb',label='no binding')],
              loc='upper left',bbox_to_anchor=(0,-0.05),ncol=4,frameon=False,fontsize=9,handlelength=1.1,columnspacing=1.4,labelcolor='#8a8a86')
    fig.suptitle(title,fontsize=12.5,y=0.965,x=0.5,fontweight='bold',color='#6b6b67')
    fig.text(0.5,0.905,subtitle,ha='center',fontsize=9.5,color='#a5a5a0')
    save(fig,fname)

# %% [markdown]
# ### Spider (radar) enrichment

# %%
def spider(enr,sig,meta,cl_order,name,title):
    axis_tags=[]; sector=[]
    for c in cl_order:
        cnt=0
        for t in sig[sig.cluster==c].sort_values('obs_exp',ascending=False).tag.tolist():
            if t not in axis_tags: axis_tags.append(t); sector.append(c); cnt+=1
            if cnt>=6: break
    if len(axis_tags)<3: return
    oe=enr.pivot(index='cluster',columns='tag',values='obs_exp').fillna(0)
    ang=np.linspace(0,2*np.pi,len(axis_tags),endpoint=False); rmax=max(6,float(np.ceil(sig['obs_exp'].max())))
    fig=plt.figure(figsize=(9.6,9.6)); axp=fig.add_subplot(111,polar=True)
    axp.set_theta_offset(np.pi/2); axp.set_theta_direction(-1); axp.set_ylim(0,rmax+1)
    ticks=list(range(1,int(rmax)+1,max(1,int(rmax)//6))); axp.set_yticks(ticks)
    axp.set_yticklabels([f'{t}×' for t in ticks],fontsize=7.5,color='#a5a5a0')
    axp.set_xticks(ang); axp.set_xticklabels([]); axp.spines['polar'].set_color('#d5d5d0'); axp.grid(color='#e6e6e2',lw=0.7)
    axp.plot(np.linspace(0,2*np.pi,200),[1]*200,color='#b5b5b0',lw=1.0,ls=(0,(4,3)),zorder=2)
    ac=np.concatenate([ang,ang[:1]])
    for c in cl_order:
        v=np.array([oe.loc[c,t] if t in oe.columns else 0 for t in axis_tags]); v=np.concatenate([v,v[:1]])
        axp.plot(ac,v,color=meta[c]['color'],lw=2.4,zorder=5,solid_joinstyle='round'); axp.fill(ac,v,color=meta[c]['color'],alpha=0.13,zorder=3)
    for a,t,c in zip(ang,axis_tags,sector):
        deg=np.degrees(a); rot=90-deg; ha='left'
        if 90<deg<270: rot+=180; ha='right'
        axp.text(a,rmax+1.2,t,rotation=rot,rotation_mode='anchor',ha=ha,va='center',fontsize=8.2,color=meta[c]['color'],fontweight='bold')
    axp.legend(handles=[plt.Line2D([0],[0],color=meta[c]['color'],lw=3,label=f"{meta[c]['name']} (n={meta[c]['size']})") for c in cl_order],
               loc='upper center',bbox_to_anchor=(0.5,-0.055),ncol=2,frameon=False,fontsize=9.3,handlelength=1.6,columnspacing=2.2,labelspacing=0.6,labelcolor='#6b6b67')
    fig.text(0.5,0.965,title,ha='center',fontsize=13,fontweight='bold',color='#6b6b67')
    fig.text(0.5,0.935,'radius = observed / expected odor-tag frequency  ·  FDR < 0.05',ha='center',fontsize=9.5,color='#a5a5a0')
    save(fig,f'spider_{name}')

# %% [markdown]
# ### Enrichment heatmap (dotted, log₂ fold)

# %%
def enrichment_heatmap(enr,sig,meta,cl_order,name,title):
    sig_tags=sig.tag.unique().tolist()
    owner={}; strength={}
    for t in sig_tags:
        sub=enr[(enr.tag==t)&(enr.cluster.isin(cl_order))]; best=sub.loc[sub.obs_exp.idxmax()]
        owner[t]=int(best.cluster); strength[t]=best.obs_exp
    tags=sorted(sig_tags,key=lambda t:(cl_order.index(owner[t]),-strength[t]))
    oe=enr.pivot(index='cluster',columns='tag',values='obs_exp'); fdr=enr.pivot(index='cluster',columns='tag',values='fdr')
    L=np.zeros((len(cl_order),len(tags)))
    for i,c in enumerate(cl_order):
        for j,t in enumerate(tags):
            v=oe.loc[c,t] if t in oe.columns else 0; L[i,j]=max(0.0,np.log2(v)) if v>0 else 0.0
    fig,ax=plt.subplots(figsize=(max(9,0.34*len(tags)),3.6))
    im=ax.imshow(L,aspect='auto',cmap='Greys',vmin=0,vmax=np.ceil(L.max()))
    ax.set_xticks(range(len(tags))); ax.set_yticks(range(len(cl_order)))
    ax.set_xticklabels(tags,rotation=90,fontsize=8)
    ax.set_yticklabels([f'C{i+1}  '+SHORT.get(meta[c]['name'],'') for i,c in enumerate(cl_order)],fontsize=9)
    for j,t in enumerate(tags): ax.get_xticklabels()[j].set_color(meta[owner[t]]['color'])
    for i,c in enumerate(cl_order): ax.get_yticklabels()[i].set_color(meta[c]['color']); ax.get_yticklabels()[i].set_fontweight('bold')
    ax.set_xticks(np.arange(-.5,len(tags),1),minor=True); ax.set_yticks(np.arange(-.5,len(cl_order),1),minor=True)
    ax.grid(which='minor',color='white',lw=1.2); ax.tick_params(which='minor',length=0)
    for i,c in enumerate(cl_order):
        for j,t in enumerate(tags):
            q=fdr.loc[c,t] if t in fdr.columns else 1; v=oe.loc[c,t] if t in oe.columns else 0
            if q<0.05 and v>1: ax.plot(j,i,'o',mfc='white',mec='#333',mew=0.6,ms=4.2,zorder=5)
    cb=fig.colorbar(im,ax=ax,fraction=0.025,pad=0.01); cb.set_label('log$_2$ fold-enrichment',fontsize=9,color='#8a8a86'); cb.ax.tick_params(labelsize=8)
    ax.set_title(title,fontsize=12,fontweight='bold',pad=10,color='#6b6b67')
    save(fig,f'enrichment_{name}')

# %% [markdown]
# ### PCoA — principal coordinate analysis of the co-tuning space
# Classical (metric) MDS: embeds the molecules from their pairwise **Jaccard** dissimilarity (shared receptor activation — the same distance used for clustering) into Euclidean axes that best preserve those distances. PCoA rather than PCA because Jaccard is non-Euclidean. Axes are ordered by variance explained (eigenvalue share); points close together activate similar receptor sets; colour = PAM cluster.

# %%
def pcoa(D):
    D=np.asarray(D,float); n=len(D); D2=D**2
    J=np.eye(n)-np.ones((n,n))/n; B=-0.5*J.dot(D2).dot(J)
    ev,evec=np.linalg.eigh((B+B.T)/2); idx=np.argsort(ev)[::-1]; ev=ev[idx]; evec=evec[:,idx]
    pos=ev>1e-9; return evec[:,pos]*np.sqrt(ev[pos]), ev
def pcoa_plot(Xn,lab,meta,cl_order,name,title):
    Dj=np.nan_to_num(squareform(pdist(Xn.T,"jaccard"))); coords,ev=pcoa(Dj)
    tot=ev[ev>0].sum(); v1,v2=100*ev[0]/tot,100*ev[1]/tot
    neg=100*(-ev[ev<0].sum())/(np.abs(ev).sum())
    fig,ax=plt.subplots(figsize=(7.6,6.8))
    for c in cl_order:
        m=lab==c; P=coords[m,:2]
        ax.scatter(P[:,0],P[:,1],s=15,color=meta[c]["color"],alpha=0.75,edgecolor="none",label=f'{meta[c]["name"]} (n={meta[c]["size"]})',zorder=3)
    ax.axhline(0,color="#e5e5e2",lw=0.6,zorder=0); ax.axvline(0,color="#e5e5e2",lw=0.6,zorder=0)
    ax.set_xlabel(f"PCo1 ({v1:.1f}%)",fontsize=10.5,color="#8a8a86"); ax.set_ylabel(f"PCo2 ({v2:.1f}%)",fontsize=10.5,color="#8a8a86")
    for sp in ["top","right"]: ax.spines[sp].set_visible(False)
    ax.tick_params(labelsize=8); ax.legend(frameon=False,fontsize=8.3,loc="best",labelcolor="#6b6b67")
    ax.set_title(title,fontsize=12.5,fontweight="bold",color="#6b6b67")
    ax.text(0.99,0.01,f"non-Euclidean (neg. eigenvalue mass {neg:.0f}%)",transform=ax.transAxes,ha="right",va="bottom",fontsize=7,color="#b5b5b0")
    save(fig,f"pcoa_{name}")

# %% [markdown]
# ## 6 · Build the four matrices

# %% [markdown]
# ### Enrichment bar plot — fold enrichment, q-value labels (screenshot style)

# %%
def _fmtq(q):
    if q<1e-5: return 'q<1e-5'
    if q<1e-3: return 'q=%.0e'%q
    return 'q=%.3f'%q

def enrichment_bars(enr,sig,meta,cl_order,name,title):
    rows=[]
    for c in cl_order:
        for r in sig[sig.cluster==c].sort_values('obs_exp',ascending=False).itertuples():
            rows.append((c,r.tag,r.obs_exp,r.fdr))
    if not rows: return
    ys=[]; labels=[]; colors=[]; folds=[]; qs=[]; y=0; last=None
    for c,tag,fold,q in rows:
        if last is not None and c!=last: y-=1
        ys.append(y); labels.append(tag); colors.append(meta[c]['color']); folds.append(fold); qs.append(q); y-=1; last=c
    ys=np.array(ys); folds=np.array(folds)
    fig,ax=plt.subplots(figsize=(8.6,0.3*(len(labels)+len(cl_order))+1))
    ax.barh(ys,folds,color=colors,alpha=0.92,height=0.74)
    ax.axvline(1,color='#8a8a86',ls='--',lw=1.0)
    xm=folds.max()
    for yi,f,q in zip(ys,folds,qs): ax.text(f+xm*0.015,yi,_fmtq(q),va='center',ha='left',fontsize=7.6,color='#8a8a86')
    ax.set_yticks(ys); ax.set_yticklabels(labels,fontsize=8.5)
    for tl,c in zip(ax.get_yticklabels(),colors): tl.set_color(c)
    ax.set_xlim(0,xm*1.30); ax.set_ylim(ys.min()-1,ys.max()+1)
    ax.set_xlabel('fold enrichment of odour descriptor  (observed / expected)',fontsize=10)
    ax.set_title(title,fontsize=12,fontweight='bold',color='#6b6b67')
    for sp in ['top','right','left']: ax.spines[sp].set_visible(False)
    ax.tick_params(left=False)
    save(fig,f'enrichbar_{name}')

# %% [markdown]
# ### Chemistry figures — Class I vs II (receptor-level) and clusters (Kruskal-Wallis), as two separate figures

# %%
from scipy.stats import kruskal
def _cliffs(a,b):
    a=np.asarray(a,float); b=np.asarray(b,float)
    return float(np.sign(a[:,None]-b[None,:]).mean())
def chem_panels(lig, Xn, lab, meta, cl_order, name, min_lig=3):
    keys=['OxygenAtoms','HBD','TPSA','RotBonds','AromaticRings','LogP','RingCount','FracCSP3']
    vals={k:np.full(len(lig),np.nan) for k in keys}
    for i,sid in enumerate(lig):
        sm=sml2smiles.get(sid); mol=Chem.MolFromSmiles(sm) if isinstance(sm,str) else None
        if mol is None: continue
        vals['OxygenAtoms'][i]=sum(a.GetAtomicNum()==8 for a in mol.GetAtoms())
        vals['HBD'][i]=Lipinski.NumHDonors(mol); vals['TPSA'][i]=rdMolDescriptors.CalcTPSA(mol)
        vals['RotBonds'][i]=Descriptors.NumRotatableBonds(mol); vals['AromaticRings'][i]=rdMolDescriptors.CalcNumAromaticRings(mol)
        vals['LogP'][i]=Crippen.MolLogP(mol); vals['RingCount'][i]=rdMolDescriptors.CalcNumRings(mol); vals['FracCSP3'][i]=rdMolDescriptors.CalcFractionCSP3(mol)
    valid=~np.isnan(vals['LogP'])

    # ---------- Figure 1 : Class I vs Class II (receptor-level, z-scored) ----------
    descA=[('OxygenAtoms','oxygen\natoms'),('HBD','H-bond\ndonors'),('TPSA','polar surf.\n(TPSA)'),
           ('RotBonds','rotatable\nbonds'),('AromaticRings','aromatic\nrings'),('LogP','lipophilicity\n(LogP)')]
    reccls=[]; recval={d[0]:[] for d in descA}
    for r in range(len(hum_pids)):
        b=np.where(Xn[r]>0)[0]; b=b[valid[b]]
        if len(b)<min_lig: continue   # stable per-receptor mean
        reccls.append(pid2class[hum_pids[r]])
        for k in recval: recval[k].append(float(np.nanmean(vals[k][b])))
    reccls=np.array(reccls)
    z={k:(np.array(v)-np.mean(v))/(np.std(v)+1e-9) for k,v in recval.items()}
    nI=int((reccls=='I').sum()); nII=int((reccls=='II').sum())
    fig,axA=plt.subplots(figsize=(9,5.6))
    for i,(k,lb) in enumerate(descA):
        zI=z[k][reccls=='I']; zII=z[k][reccls=='II']
        vp=axA.violinplot([zI,zII],positions=[i*2,i*2+0.9],widths=0.8,showmedians=False,showextrema=False)
        for pc,cc in zip(vp['bodies'],[CLASS_I_COL,CLASS_II_COL]): pc.set_facecolor(cc); pc.set_alpha(0.78); pc.set_edgecolor('none')
        for pos,vv in [(i*2,zI),(i*2+0.9,zII)]:
            a1,md,a3=np.percentile(vv,[25,50,75]); axA.vlines(pos,a1,a3,color='#333',lw=3); axA.plot(pos,md,'o',mfc='white',mec='#333',ms=4,zorder=5)
        d=_cliffs(zI,zII); pv=mannwhitneyu(zI,zII).pvalue
        s='***' if pv<1e-3 else '**' if pv<1e-2 else '*' if pv<0.05 else 'ns'
        axA.text(i*2+0.45,3.6,s,ha='center',fontsize=10,color='#6b6b67')
        axA.text(i*2+0.45,3.05,'\u03b4=%+.2f'%d,ha='center',fontsize=8,color='#8a8a86')
    axA.axhline(0,color='#ccc',lw=0.8,zorder=0)
    axA.set_xticks([i*2+0.45 for i in range(len(descA))]); axA.set_xticklabels([lb for _,lb in descA],fontsize=9)
    axA.set_ylabel("chemistry of the receptor's ligand set (z-score)",fontsize=10); axA.set_ylim(-3,4.2)
    for sp in ['top','right']: axA.spines[sp].set_visible(False)
    axA.legend(handles=[Patch(fc=CLASS_I_COL,label='Class I  (n=%d)'%nI),Patch(fc=CLASS_II_COL,label='Class II (n=%d)'%nII)],frameon=False,fontsize=9,loc='lower left')
    axA.set_title('The two ancient receptor classes read different chemistry\nClass I: polar, H-bonding aliphatics \u00b7 Class II: aromatic, lipophilic',fontsize=11,fontweight='bold',loc='left',color='#6b6b67')
    save(fig,f'chemistry_class_{name}')

    # ---------- Figure 2 : clusters (odorant-level, Kruskal-Wallis) ----------
    descB=[('RingCount','rings'),('FracCSP3','sp\u00b3 fraction'),('LogP','lipophilicity (LogP)')]
    kwset=['RingCount','FracCSP3','LogP','TPSA','AromaticRings','OxygenAtoms','RotBonds','HBD']
    kwp={}
    for k in kwset:
        try: kwp[k]=kruskal(*[vals[k][(lab==c)&valid] for c in cl_order])[1]
        except Exception: kwp[k]=np.nan
    ks=list(kwp); pp=np.array([kwp[k] for k in ks]); mm=len(pp); oo=np.argsort(pp); q=np.empty(mm); rk=pp[oo]
    q[oo]=np.clip(np.minimum.accumulate((rk*mm/(np.arange(mm)+1))[::-1])[::-1],0,1); qmap=dict(zip(ks,q))
    fq=lambda x: ('q=%.0e'%x if x<1e-3 else 'q=%.2f'%x)
    fig,axB=plt.subplots(1,3,figsize=(8.4,4.3))
    for ax,(k,lb) in zip(axB,descB):
        data=[vals[k][(lab==c)&valid] for c in cl_order]
        vp=ax.violinplot(data,positions=range(len(cl_order)),widths=0.85,showmedians=False,showextrema=False)
        for pc,c in zip(vp['bodies'],cl_order): pc.set_facecolor(meta[c]['color']); pc.set_alpha(0.78); pc.set_edgecolor('none')
        for j,vv in enumerate(data):
            a1,md,a3=np.percentile(vv,[25,50,75]); ax.vlines(j,a1,a3,color='#333',lw=2.5); ax.plot(j,md,'o',mfc='white',mec='#333',ms=4,zorder=5)
        H=kruskal(*data)[0]
        ax.set_title('%s\nH=%.0f, %s'%(lb,H,fq(qmap.get(k,np.nan))),fontsize=10,color='#6b6b67')
        ax.set_xticks(range(len(cl_order))); ax.set_xticklabels(['C%d'%(i+1) for i in range(len(cl_order))],fontsize=8.5)
        for tl,c in zip(ax.get_xticklabels(),cl_order): tl.set_color(meta[c]['color'])
        for sp in ['top','right']: ax.spines[sp].set_visible(False)
    axB[0].set_ylabel('descriptor value',fontsize=10)
    fig.suptitle('Activation Clusters',fontsize=11,fontweight='bold',color='#6b6b67')
    fig.tight_layout(rect=[0,0,1,0.94])
    save(fig,f'chemistry_clusters_{name}')

# %%
ridx={p:i for i,p in enumerate(hum_pids)}; cidx={c:j for j,c in enumerate(lig_cols)}
base=(Pv>=0.50).astype(int); calib=(Pv>CALIB_THR).astype(int)
hybrid_05=base.copy(); hybrid_083=calib.copy()
for r in exp.itertuples():
    hybrid_05[ridx[r.pid],cidx[r.smiles_id]]=int(r.Responsive)
    hybrid_083[ridx[r.pid],cidx[r.smiles_id]]=int(r.Responsive)
print('densities  base=%.4f calib=%.4f hybrid_0.5=%.4f hybrid_0.83=%.4f'%(base.mean(),calib.mean(),hybrid_05.mean(),hybrid_083.mean()))

def run_matrix(name,X,title,subtitle):
    lig,Xn,lab,enr,sig,meta,cl_order=cluster_and_enrich(X)
    enr.sort_values(['cluster','fdr']).to_csv(f'{OUTDIR}/enrichment_{name}.csv',index=False)
    activation_heatmap(lig,Xn,lab,meta,cl_order,name,title,subtitle,'cotuning')
    activation_heatmap(lig,Xn,lab,meta,cl_order,name,title,subtitle,'tree')
    spider(enr,sig,meta,cl_order,name,'Perceptual enrichment — '+name)
    enrichment_heatmap(enr,sig,meta,cl_order,name,'Perceptual enrichment — '+name)
    enrichment_bars(enr,sig,meta,cl_order,name,'Odour-descriptor enrichment — '+name)
    chem_panels(lig,Xn,lab,meta,cl_order,name)
    pcoa_plot(Xn,lab,meta,cl_order,name,'PCoA of odorant co-tuning (Jaccard) — '+name)
    print('%-12s sizes %s  #sig %d'%(name,sorted([meta[c]['size'] for c in cl_order],reverse=True),len(sig)))
# Out:
# densities  base=0.1356 calib=0.0512 hybrid_0.5=0.1266 hybrid_0.83=0.0481

# %% [markdown]
# ## 7 · Baseline / Calibrated / Hybrid 0.5 / Hybrid 0.83

# %%
run_matrix('baseline',   base,       'Baseline landscape (p ≥ 0.50)',                       'released prediction file')
run_matrix('calibrated', calib,      'Calibrated landscape (p > 0.83)',                      'high-confidence predictions')
run_matrix('hybrid_0.5', hybrid_05,  'Hybrid landscape (M2OR truth + baseline p ≥ 0.50 fill)','experimental where available, else p ≥ 0.50')
run_matrix('hybrid_0.83',hybrid_083, 'Hybrid landscape (M2OR truth + calibrated p > 0.83 fill)','experimental where available, else p > 0.83')
# Out:
# baseline     sizes [184, 156, 132, 130, 84, 65]  #sig 37
# calibrated   sizes [141, 135, 133, 125, 109, 83]  #sig 40
# hybrid_0.5   sizes [167, 150, 141, 123, 114, 57]  #sig 29
# hybrid_0.83  sizes [145, 144, 141, 119, 103, 79]  #sig 43

# %% [markdown]
# ## 8 · Chemical space of Class I- vs Class II-preferring odorants (one figure per matrix)

# %%
_FG={'carboxylic acid':'[CX3](=O)[OX2H1]','ester':'[CX3](=O)[OX2H0][#6]','aldehyde':'[CX3H1](=O)[#6]',
     'ketone':'[#6][CX3](=O)[#6]','alcohol':'[#6;!$([CX3]=O)][OX2H1]','ether':'[OD2]([#6])[#6]',
     'aromatic ring':'c1ccccc1','amine':'[NX3;!$([NX3][CX3]=[OX1])]','sulfur':'[#16]'}
_FGP={k:Chem.MolFromSmarts(v) for k,v in _FG.items()}

def _cliffs(a,b):
    a=np.asarray(a,float); b=np.asarray(b,float)
    return float(np.sign(a[:,None]-b[None,:]).mean())   # >0 => Class I larger

def chemical_space(Xbind,name):
    isI=np.array([pid2class[p]=='I' for p in hum_pids]); isII=~isI; NI,NII=isI.sum(),isII.sum()
    recs=[]
    for j,sid in enumerate(lig_cols):
        col=Xbind[:,j]; nI=int(col[isI].sum()); nII=int(col[isII].sum())
        if nI==0 and nII==0: continue
        pref='I' if (nI/NI)>(nII/NII) else 'II'
        sm=sml2smiles.get(sid); mol=Chem.MolFromSmiles(sm) if isinstance(sm,str) else None
        if mol is None: continue
        d=dict(sml=sid,pref=pref,MolWt=Descriptors.MolWt(mol),LogP=Crippen.MolLogP(mol),TPSA=rdMolDescriptors.CalcTPSA(mol),
            HBD=Lipinski.NumHDonors(mol),HBA=Lipinski.NumHAcceptors(mol),AromaticRings=rdMolDescriptors.CalcNumAromaticRings(mol),
            RotBonds=Descriptors.NumRotatableBonds(mol),RingCount=rdMolDescriptors.CalcNumRings(mol),
            FracCSP3=rdMolDescriptors.CalcFractionCSP3(mol),Heteroatoms=Lipinski.NumHeteroatoms(mol))
        for g,patt in _FGP.items(): d[g]=int(mol.HasSubstructMatch(patt))
        recs.append(d)
    df=pd.DataFrame(recs); df.to_csv(f'{OUTDIR}/chemspace_{name}_descriptors.csv',index=False)
    gI=df[df.pref=='I']; gII=df[df.pref=='II']
    props=[('MolWt','MW (Da)'),('LogP','cLogP'),('TPSA','TPSA (Å²)'),('HBD','H-bond donors'),('HBA','H-bond acceptors'),
           ('AromaticRings','aromatic rings'),('RotBonds','rotatable bonds'),('RingCount','ring count'),('FracCSP3','fraction sp³'),('Heteroatoms','heteroatoms')]

    # (a) descriptor violins
    fig,axes=plt.subplots(2,5,figsize=(16,7)); axes=axes.ravel()
    for ax,(k,lab) in zip(axes,props):
        a,b=gI[k].values,gII[k].values; parts=ax.violinplot([a,b],showmedians=True,widths=0.85)
        for pc,col in zip(parts['bodies'],[CLASS_I_COL,CLASS_II_COL]): pc.set_facecolor(col); pc.set_alpha(0.65); pc.set_edgecolor('#333')
        for key in ['cmedians','cmaxes','cmins','cbars']: parts[key].set_color('#555'); parts[key].set_linewidth(1.0)
        try: p=mannwhitneyu(a,b,alternative='two-sided').pvalue
        except Exception: p=np.nan
        ax.set_title('%s\nMWU p=%.1e'%(lab,p),fontsize=9.5,color='#6b6b67')
        ax.set_xticks([1,2]); ax.set_xticklabels(['Class I','Class II'],fontsize=8.5); ax.tick_params(axis='y',labelsize=8)
        for sp in ['top','right']: ax.spines[sp].set_visible(False)
    fig.suptitle('Chemical space of Class I- vs Class II-preferring odorants — %s  ·  n(I)=%d, n(II)=%d'%(name,len(gI),len(gII)),fontsize=13,fontweight='bold',y=1.0,color='#6b6b67')
    fig.tight_layout(rect=[0,0,1,0.97]); save(fig,f'chemspace_{name}')

    # (b) functional groups (incl. carboxylic acids) — all in one plot
    from scipy.stats import fisher_exact
    groups=list(_FG.keys())
    fracI=[100*gI[g].mean() for g in groups]; fracII=[100*gII[g].mean() for g in groups]
    pg=[]
    for g in groups:
        a1=int(gI[g].sum()); a2=int(gII[g].sum())
        try: pg.append(fisher_exact([[a1,len(gI)-a1],[a2,len(gII)-a2]])[1])
        except Exception: pg.append(np.nan)
    o=np.argsort(fracI); groups=[groups[i] for i in o]; fracI=[fracI[i] for i in o]; fracII=[fracII[i] for i in o]; pg=[pg[i] for i in o]
    yy=np.arange(len(groups)); hh=0.38
    fig,ax=plt.subplots(figsize=(8.6,0.6*len(groups)+1.2))
    ax.barh(yy+hh/2,fracI,height=hh,color=CLASS_I_COL,alpha=0.9,label='Class I-preferring')
    ax.barh(yy-hh/2,fracII,height=hh,color=CLASS_II_COL,alpha=0.9,label='Class II-preferring')
    xm=max(max(fracI),max(fracII))
    for yi,p in zip(yy,pg):
        s='***' if p<1e-3 else '**' if p<1e-2 else '*' if p<0.05 else 'ns'
        ax.text(xm*1.02,yi,s,va='center',fontsize=9,color='#8a8a86')
    ax.set_yticks(yy); ax.set_yticklabels(groups,fontsize=9)
    ax.set_xlabel('% of odorants containing group',fontsize=10); ax.set_xlim(0,xm*1.15)
    ax.legend(frameon=False,fontsize=9,loc='lower right')
    ax.set_title('Functional groups — %s'%name,fontsize=12,fontweight='bold',color='#6b6b67')
    for sp in ['top','right']: ax.spines[sp].set_visible(False)
    save(fig,f'chemspace_{name}_groups')

    # (c) effect sizes — what differs most (lipophilicity, rings, sp3, ...)
    desc=[k for k,_ in props]; labm=dict(props); eff=[]; pv=[]
    for k in desc:
        eff.append(_cliffs(gI[k].values,gII[k].values))
        try: pv.append(mannwhitneyu(gI[k].values,gII[k].values).pvalue)
        except Exception: pv.append(np.nan)
    pv=np.array(pv); mm=len(pv); oo=np.argsort(pv); q=np.empty(mm); rk=pv[oo]
    q[oo]=np.clip(np.minimum.accumulate((rk*mm/(np.arange(mm)+1))[::-1])[::-1],0,1)
    idx=np.argsort(eff); eff=np.array(eff)[idx]; dl=[labm[desc[i]] for i in idx]; q=q[idx]
    fig,ax=plt.subplots(figsize=(8,0.5*len(dl)+1.2))
    cols=[CLASS_I_COL if e>0 else CLASS_II_COL for e in eff]
    ax.barh(range(len(dl)),eff,color=cols,alpha=0.9); ax.axvline(0,color='#c9c9c4',lw=0.8)
    xr=max(abs(eff.min()),abs(eff.max()),0.05)
    for i,(e,qq) in enumerate(zip(eff,q)):
        s='***' if qq<1e-3 else '**' if qq<1e-2 else '*' if qq<0.05 else 'ns'
        ax.text(e+0.03*xr*(1 if e>=0 else -1),i,s,va='center',ha='left' if e>=0 else 'right',fontsize=8.5,color='#8a8a86')
    ax.set_yticks(range(len(dl))); ax.set_yticklabels(dl,fontsize=9); ax.set_xlim(-xr*1.3,xr*1.3)
    ax.set_xlabel('effect size (Cliff delta)    <- Class II higher   |   Class I higher ->',fontsize=9.5)
    ax.set_title('What differs most — %s'%name,fontsize=12,fontweight='bold',color='#6b6b67')
    for sp in ['top','right']: ax.spines[sp].set_visible(False)
    save(fig,f'chemspace_{name}_effects')
    print('chemspace %-11s n(I)=%d n(II)=%d'%(name,len(gI),len(gII)))

for _nm,_X in [('baseline',base),('calibrated',calib),('hybrid_0.5',hybrid_05),('hybrid_0.83',hybrid_083)]:
    chemical_space(_X,_nm)
# Out:
# chemspace baseline    n(I)=443 n(II)=308
# chemspace calibrated  n(I)=337 n(II)=389
# chemspace hybrid_0.5  n(I)=449 n(II)=303
# chemspace hybrid_0.83 n(I)=341 n(II)=390

# %% [markdown]
# ## Notes
# - `hybrid_0.5` and `hybrid_0.83` share the same 23,782 experimental cells; they differ only in the predicted fill (p ≥ 0.50 vs p > 0.83).
# - Each matrix yields `heatmap_{name}` (co-tuning row order) and `heatmap_{name}_tree_order` (phylogenetic row order); enrichment shown both as `spider_{name}` and `enrichment_{name}`.
# - Chemical space uses the calibrated matrix to assign preferential class binding; edit `chemical_space(...)` to use another matrix or exclusive binders.
